# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt

df = pd.read_csv(r'C:\Users\fabri\Desktop\MarcoPatierno_DepositoCorsoPython\env\Giorno 19 29-04\esercitazione_house\kc_house_data.csv')

# Conversione data in datetime
df['date'] = df['date'].str.replace('T000000', '', regex=False)

df["date"] = pd.to_datetime(df["date"], format="%Y%m%d")
df["date"].head()

# Sostituzione dei valori di yr_renovated
df['yr_renovated'] = pd.cut(df['yr_renovated'], bins=[-1, 0, 1980, 2000, float('inf')], labels=[0, 1, 2, 3])

# Visualizza le prime righe per verificare la sostituzione
df['yr_renovated'].head()

X = df.drop(columns=["price", "date", "id"]) #, "lat", "long", "zipcode"
y = df["price"]

scaler = StandardScaler()   
X_scaled = scaler.fit_transform(X)
y_scaled = scaler.fit_transform(y.values.reshape(-1, 1))

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

def elimina_variabili_vif_pvalue(X_train, y_train,
                                 vif_threshold=10.0,
                                 pvalue_threshold=0.05):
    # Se non è già un DataFrame, lo trasformo
    if not isinstance(X_train, pd.DataFrame):
        X_current = pd.DataFrame(
            X_train,
            columns=[f"x{i}" for i in range(X_train.shape[1])]
        )
    else:
        X_current = X_train.copy()

    while True:
        # Aggiungo costante (ora X_current è DataFrame)
        X_const = sm.add_constant(X_current)
        model   = sm.OLS(y_train, X_const).fit()

        # Prendo i p-value come Series e tolgo la costante
        pvalues = pd.Series(model.pvalues, index=X_const.columns)
        pvalues = pvalues.drop('const')

        # Calcolo il VIF
        vif = pd.DataFrame({
            "Feature": X_current.columns,
            "VIF": [
                variance_inflation_factor(X_current.values, i)
                for i in range(X_current.shape[1])
            ]
        })

        # Unisco VIF e p-value
        stats = vif.copy()
        stats["p-value"] = pvalues.values

        # Seleziono candidati con VIF e p-value alti
        candidates = stats[
            (stats["VIF"] > vif_threshold) &
            (stats["p-value"] > pvalue_threshold)
        ]
        if candidates.empty:
            print("\nNessuna variabile da eliminare. Selezione completata.")
            break

        # Rimuovo la feature peggiore
        worst = candidates.sort_values(by="VIF", ascending=False).iloc[0]
        feat = worst["Feature"]
        print(f"Rimuovo '{feat}' (VIF={worst['VIF']:.2f}, p-value={worst['p-value']:.4f})")

        X_current = X_current.drop(columns=[feat])

    print("\nFeature finali selezionate:")
    print(X_current.columns.tolist())
    return X_current

# %%
X_current = elimina_variabili_vif_pvalue(X_train, y_train, vif_threshold=10.0, pvalue_threshold=0.05)
# Out:
# c:\Users\fabri\Desktop\MarcoPatierno_DepositoCorsoPython\env\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# Nessuna variabile da eliminare. Selezione completata.
#
# Feature finali selezionate:
# ['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17']

# %%
import xgboost as xgb
from itertools import product

# --- Assumiamo che X_current e y_train siano già definiti ---
# dtrain = DMatrix dei tuoi dati
dtrain = xgb.DMatrix(X_current, label=y_train)

# --- Griglia di tutti gli iperparametri da esplorare ---
param_grid = {
    'alpha':          [0, 0.1, 0.3, 0.5, 0.7, 1],
    'lambda':         [0, 0.1, 0.3, 0.5, 0.7, 1],
    'max_depth':      [3, 4, 5, 6],
    'eta':            [0.01, 0.05, 0.1, 0.2],
    'subsample':      [0.7, 0.8, 0.9, 1.0],
    'colsample_bytree':[0.7, 0.8, 0.9, 1.0]
}

best_params = {}
best_rmse = float("inf")

print("Stage unico: ottimizzazione completa su X_current, y_train")

# --- Ciclo su ogni combinazione di iperparametri ---
for alpha, lambda_val, max_depth, eta, subsample, colsample in product(
        param_grid['alpha'],
        param_grid['lambda'],
        param_grid['max_depth'],
        param_grid['eta'],
        param_grid['subsample'],
        param_grid['colsample_bytree']
    ):
    # Costruisco i parametri per questa iterazione
    params = {
        'objective':        'reg:squarederror',
        'alpha':            alpha,
        'lambda':           lambda_val,
        'max_depth':        max_depth,
        'eta':               eta,
        'subsample':        subsample,
        'colsample_bytree': colsample
    }

    # Eseguo la cross‐validation con early stopping
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=100,
        nfold=5,
        metrics="rmse",
        early_stopping_rounds=10,
        seed=42,
        verbose_eval=False
    )
    # Estraggo il valore minimo di test-rmse-mean
    mean_rmse = cv_results['test-rmse-mean'].min()

    # Stampo lo stato corrente (opzionale ma utile per monitorare)
    print(f"α={alpha:.1f}, λ={lambda_val:.1f}, depth={max_depth}, η={eta:.2f}, "
          f"sub={subsample}, col={colsample} → RMSE: {mean_rmse:.4f}")

    # Aggiorno il miglior risultato trovato
    if mean_rmse < best_rmse:
        best_rmse = mean_rmse
        best_params = {
            'alpha':            alpha,
            'lambda':           lambda_val,
            'max_depth':        max_depth,
            'eta':               eta,
            'subsample':        subsample,
            'colsample_bytree': colsample
        }

# --- Output dei migliori iperparametri ---
print("\nMigliori parametri trovati:")
for k, v in best_params.items():
    print(f"  • {k}: {v}")
print(f"Con RMSE = {best_rmse:.4f}")
# Out:
# Stage unico: ottimizzazione completa su X_current, y_train
# α=0.0, λ=0.0, depth=3, η=0.01, sub=0.7, col=0.7 → RMSE: 60.3890
# α=0.0, λ=0.0, depth=3, η=0.01, sub=0.7, col=0.8 → RMSE: 60.3273
# α=0.0, λ=0.0, depth=3, η=0.01, sub=0.7, col=0.9 → RMSE: 60.0812
# α=0.0, λ=0.0, depth=3, η=0.01, sub=0.7, col=1.0 → RMSE: 59.8904
# α=0.0, λ=0.0, depth=3, η=0.01, sub=0.8, col=0.7 → RMSE: 60.4859
# α=0.0, λ=0.0, depth=3, η=0.01, sub=0.8, col=0.8 → RMSE: 60.2801
# α=0.0, λ=0.0, depth=3, η=0.01, sub=0.8, col=0.9 → RMSE: 60.1921
# α=0.0, λ=0.0, depth=3, η=0.01, sub=0.8, col=1.0 → RMSE: 60.1197
# α=0.0, λ=0.0, depth=3, η=0.01, sub=0.9, col=0.7 → RMSE: 60.5695
# α=0.0, λ=0.0, depth=3, η=0.01, sub=0.9, col=0.8 → RMSE: 60.3906
# α=0.0, λ=0.0, depth=3, η=0.01, sub=0.9, col=0.9 → RMSE: 60.2182
# α=0.0, λ=0.0, depth=3, η=0.01, sub=0.9, col=1.0 → RMSE: 60.1731
# α=0.0, λ=0.0, depth=3, η=0.01, sub=1.0, col=0.7 → RMSE: 60.8071
# α=0.0, λ=0.0, depth=3, η=0.01, sub=1.0, col=0.8 → RMSE: 60.7164
# α=0.0, λ=0.0, depth=3, η=0.01, sub=1.0, col=0.9 → RMSE: 60.5823
# α=0.0, λ=0.0, depth=3, η=0.01, sub=1.0, col=1.0 → RMSE: 60.6188
# α=0.0, λ=0.0, depth=3, η=0.05, sub=0.7, col=0.7 → RMSE: 55.9641
# α=0.0, λ=0.0, depth=3, η=0.05, sub=0.7, col=0.8 → RMSE: 56.2633
# α=0.0, λ=0.0, depth=3, η=0.05, sub=0.7, col=0.9 → RMSE: 56.4599
# α=0.0, λ=0.0, depth=3, η=0.05, sub=0.7, col=1.0 → RMSE: 56.6057
# α=0.0, λ=0.0, depth=3, η=0.05, sub=0.8, col=0.7 → RMSE: 56.5430
# α=0.0, λ=0.0, depth=3, η=0.05, sub=0.8, col=0.8 → RMSE: 56.5121
# α=0.0, λ=0.0, depth=3, η=0.05, sub=0.8, col=0.9 → RMSE: 56.4678
# α=0.0, λ=0.0, depth=3, η=0.05, sub=0.8, col=1.0 → RMSE: 56.7795
# α=0.0, λ=0.0, depth=3, η=0.05, sub=0.9, col=0.7 → RMSE: 56.1893
# α=0.0, λ=0.0, depth=3, η=0.05, sub=0.9, col=0.8 → RMSE: 56.3064
# α=0.0, λ=0.0, depth=3, η=0.05, sub=0.9, col=0.9 → RMSE: 56.5883
# α=0.0, λ=0.0, depth=3, η=0.05, sub=0.9, col=1.0 → RMSE: 56.5673
# α=0.0, λ=0.0, depth=3, η=0.05, sub=1.0, col=0.7 → RMSE: 56.5594
# α=0.0, λ=0.0, depth=3, η=0.05, sub=1.0, col=0.8 → RMSE: 56.7302
# α=0.0, λ=0.0, depth=3, η=0.05, sub=1.0, col=0.9 → RMSE: 56.7563
# α=0.0, λ=0.0, depth=3, η=0.05, sub=1.0, col=1.0 → RMSE: 56.7804
# α=0.0, λ=0.0, depth=3, η=0.10, sub=0.7, col=0.7 → RMSE: 55.5286
# α=0.0, λ=0.0, depth=3, η=0.10, sub=0.7, col=0.8 → RMSE: 56.2939
# α=0.0, λ=0.0, depth=3, η=0.10, sub=0.7, col=0.9 → RMSE: 55.7056
# α=0.0, λ=0.0, depth=3, η=0.10, sub=0.7, col=1.0 → RMSE: 56.1839
# α=0.0, λ=0.0, depth=3, η=0.10, sub=0.8, col=0.7 → RMSE: 56.4050
# α=0.0, λ=0.0, depth=3, η=0.10, sub=0.8, col=0.8 → RMSE: 55.9387
# α=0.0, λ=0.0, depth=3, η=0.10, sub=0.8, col=0.9 → RMSE: 55.7761
# α=0.0, λ=0.0, depth=3, η=0.10, sub=0.8, col=1.0 → RMSE: 56.6472
# α=0.0, λ=0.0, depth=3, η=0.10, sub=0.9, col=0.7 → RMSE: 56.8987
# α=0.0, λ=0.0, depth=3, η=0.10, sub=0.9, col=0.8 → RMSE: 56.6569
# α=0.0, λ=0.0, depth=3, η=0.10, sub=0.9, col=0.9 → RMSE: 56.2585
# α=0.0, λ=0.0, depth=3, η=0.10, sub=0.9, col=1.0 → RMSE: 56.7322
# α=0.0, λ=0.0, depth=3, η=0.10, sub=1.0, col=0.7 → RMSE: 56.4126
# α=0.0, λ=0.0, depth=3, η=0.10, sub=1.0, col=0.8 → RMSE: 56.2057
# α=0.0, λ=0.0, depth=3, η=0.10, sub=1.0, col=0.9 → RMSE: 56.6740
# α=0.0, λ=0.0, depth=3, η=0.10, sub=1.0, col=1.0 → RMSE: 56.7944
# α=0.0, λ=0.0, depth=3, η=0.20, sub=0.7, col=0.7 → RMSE: 56.5372
# α=0.0, λ=0.0, depth=3, η=0.20, sub=0.7, col=0.8 → RMSE: 56.8578
# α=0.0, λ=0.0, depth=3, η=0.20, sub=0.7, col=0.9 → RMSE: 56.6340
# α=0.0, λ=0.0, depth=3, η=0.20, sub=0.7, col=1.0 → RMSE: 56.3819
# α=0.0, λ=0.0, depth=3, η=0.20, sub=0.8, col=0.7 → RMSE: 56.2693
# α=0.0, λ=0.0, depth=3, η=0.20, sub=0.8, col=0.8 → RMSE: 56.3453
# α=0.0, λ=0.0, depth=3, η=0.20, sub=0.8, col=0.9 → RMSE: 56.7847
# α=0.0, λ=0.0, depth=3, η=0.20, sub=0.8, col=1.0 → RMSE: 56.5267
# α=0.0, λ=0.0, depth=3, η=0.20, sub=0.9, col=0.7 → RMSE: 56.7997
# α=0.0, λ=0.0, depth=3, η=0.20, sub=0.9, col=0.8 → RMSE: 57.0642
# α=0.0, λ=0.0, depth=3, η=0.20, sub=0.9, col=0.9 → RMSE: 57.6000
# α=0.0, λ=0.0, depth=3, η=0.20, sub=0.9, col=1.0 → RMSE: 56.8689
# α=0.0, λ=0.0, depth=3, η=0.20, sub=1.0, col=0.7 → RMSE: 56.2271
# α=0.0, λ=0.0, depth=3, η=0.20, sub=1.0, col=0.8 → RMSE: 56.6115
# α=0.0, λ=0.0, depth=3, η=0.20, sub=1.0, col=0.9 → RMSE: 56.4475
# α=0.0, λ=0.0, depth=3, η=0.20, sub=1.0, col=1.0 → RMSE: 57.0883
# α=0.0, λ=0.0, depth=4, η=0.01, sub=0.7, col=0.7 → RMSE: 60.3925
# α=0.0, λ=0.0, depth=4, η=0.01, sub=0.7, col=0.8 → RMSE: 60.2191
# α=0.0, λ=0.0, depth=4, η=0.01, sub=0.7, col=0.9 → RMSE: 59.9184
# α=0.0, λ=0.0, depth=4, η=0.01, sub=0.7, col=1.0 → RMSE: 59.7816
# α=0.0, λ=0.0, depth=4, η=0.01, sub=0.8, col=0.7 → RMSE: 60.4730
# α=0.0, λ=0.0, depth=4, η=0.01, sub=0.8, col=0.8 → RMSE: 60.1426
# α=0.0, λ=0.0, depth=4, η=0.01, sub=0.8, col=0.9 → RMSE: 60.0888
# α=0.0, λ=0.0, depth=4, η=0.01, sub=0.8, col=1.0 → RMSE: 60.1690
# α=0.0, λ=0.0, depth=4, η=0.01, sub=0.9, col=0.7 → RMSE: 60.5080
# α=0.0, λ=0.0, depth=4, η=0.01, sub=0.9, col=0.8 → RMSE: 60.2067
# α=0.0, λ=0.0, depth=4, η=0.01, sub=0.9, col=0.9 → RMSE: 60.1581
# α=0.0, λ=0.0, depth=4, η=0.01, sub=0.9, col=1.0 → RMSE: 60.2690
# α=0.0, λ=0.0, depth=4, η=0.01, sub=1.0, col=0.7 → RMSE: 61.0439
# α=0.0, λ=0.0, depth=4, η=0.01, sub=1.0, col=0.8 → RMSE: 60.8257
# α=0.0, λ=0.0, depth=4, η=0.01, sub=1.0, col=0.9 → RMSE: 60.6071
# α=0.0, λ=0.0, depth=4, η=0.01, sub=1.0, col=1.0 → RMSE: 60.6718
# α=0.0, λ=0.0, depth=4, η=0.05, sub=0.7, col=0.7 → RMSE: 56.5509
# α=0.0, λ=0.0, depth=4, η=0.05, sub=0.7, col=0.8 → RMSE: 57.5057
# α=0.0, λ=0.0, depth=4, η=0.05, sub=0.7, col=0.9 → RMSE: 56.9203
# α=0.0, λ=0.0, depth=4, η=0.05, sub=0.7, col=1.0 → RMSE: 57.3624
# α=0.0, λ=0.0, depth=4, η=0.05, sub=0.8, col=0.7 → RMSE: 57.0348
# α=0.0, λ=0.0, depth=4, η=0.05, sub=0.8, col=0.8 → RMSE: 56.6453
# α=0.0, λ=0.0, depth=4, η=0.05, sub=0.8, col=0.9 → RMSE: 57.1489
# α=0.0, λ=0.0, depth=4, η=0.05, sub=0.8, col=1.0 → RMSE: 57.4949
# α=0.0, λ=0.0, depth=4, η=0.05, sub=0.9, col=0.7 → RMSE: 57.9710
# α=0.0, λ=0.0, depth=4, η=0.05, sub=0.9, col=0.8 → RMSE: 57.6416
# α=0.0, λ=0.0, depth=4, η=0.05, sub=0.9, col=0.9 → RMSE: 57.1133
# α=0.0, λ=0.0, depth=4, η=0.05, sub=0.9, col=1.0 → RMSE: 57.7598
# α=0.0, λ=0.0, depth=4, η=0.05, sub=1.0, col=0.7 → RMSE: 57.9585
# α=0.0, λ=0.0, depth=4, η=0.05, sub=1.0, col=0.8 → RMSE: 57.5350
# α=0.0, λ=0.0, depth=4, η=0.05, sub=1.0, col=0.9 → RMSE: 57.9587
# α=0.0, λ=0.0, depth=4, η=0.05, sub=1.0, col=1.0 → RMSE: 58.2199
# α=0.0, λ=0.0, depth=4, η=0.10, sub=0.7, col=0.7 → RMSE: 57.3449
# α=0.0, λ=0.0, depth=4, η=0.10, sub=0.7, col=0.8 → RMSE: 57.3534
# α=0.0, λ=0.0, depth=4, η=0.10, sub=0.7, col=0.9 → RMSE: 57.0769
# α=0.0, λ=0.0, depth=4, η=0.10, sub=0.7, col=1.0 → RMSE: 57.4199
# α=0.0, λ=0.0, depth=4, η=0.10, sub=0.8, col=0.7 → RMSE: 57.0513
# α=0.0, λ=0.0, depth=4, η=0.10, sub=0.8, col=0.8 → RMSE: 57.3146
# α=0.0, λ=0.0, depth=4, η=0.10, sub=0.8, col=0.9 → RMSE: 57.3151
# α=0.0, λ=0.0, depth=4, η=0.10, sub=0.8, col=1.0 → RMSE: 57.5824
# α=0.0, λ=0.0, depth=4, η=0.10, sub=0.9, col=0.7 → RMSE: 58.0291
# α=0.0, λ=0.0, depth=4, η=0.10, sub=0.9, col=0.8 → RMSE: 58.2872
# α=0.0, λ=0.0, depth=4, η=0.10, sub=0.9, col=0.9 → RMSE: 58.2449
# α=0.0, λ=0.0, depth=4, η=0.10, sub=0.9, col=1.0 → RMSE: 58.4408
# α=0.0, λ=0.0, depth=4, η=0.10, sub=1.0, col=0.7 → RMSE: 57.8451
# α=0.0, λ=0.0, depth=4, η=0.10, sub=1.0, col=0.8 → RMSE: 58.5903
# α=0.0, λ=0.0, depth=4, η=0.10, sub=1.0, col=0.9 → RMSE: 57.5404
# α=0.0, λ=0.0, depth=4, η=0.10, sub=1.0, col=1.0 → RMSE: 57.6502
# α=0.0, λ=0.0, depth=4, η=0.20, sub=0.7, col=0.7 → RMSE: 57.8827
# α=0.0, λ=0.0, depth=4, η=0.20, sub=0.7, col=0.8 → RMSE: 57.3905
# α=0.0, λ=0.0, depth=4, η=0.20, sub=0.7, col=0.9 → RMSE: 58.1222
# α=0.0, λ=0.0, depth=4, η=0.20, sub=0.7, col=1.0 → RMSE: 57.9529
# α=0.0, λ=0.0, depth=4, η=0.20, sub=0.8, col=0.7 → RMSE: 58.1033
# α=0.0, λ=0.0, depth=4, η=0.20, sub=0.8, col=0.8 → RMSE: 57.4956
# α=0.0, λ=0.0, depth=4, η=0.20, sub=0.8, col=0.9 → RMSE: 57.9189
# α=0.0, λ=0.0, depth=4, η=0.20, sub=0.8, col=1.0 → RMSE: 58.3100
# α=0.0, λ=0.0, depth=4, η=0.20, sub=0.9, col=0.7 → RMSE: 59.0038
# α=0.0, λ=0.0, depth=4, η=0.20, sub=0.9, col=0.8 → RMSE: 59.1792
# α=0.0, λ=0.0, depth=4, η=0.20, sub=0.9, col=0.9 → RMSE: 59.9576
# α=0.0, λ=0.0, depth=4, η=0.20, sub=0.9, col=1.0 → RMSE: 58.1880
# α=0.0, λ=0.0, depth=4, η=0.20, sub=1.0, col=0.7 → RMSE: 58.4805
# α=0.0, λ=0.0, depth=4, η=0.20, sub=1.0, col=0.8 → RMSE: 59.0712
# α=0.0, λ=0.0, depth=4, η=0.20, sub=1.0, col=0.9 → RMSE: 58.6777
# α=0.0, λ=0.0, depth=4, η=0.20, sub=1.0, col=1.0 → RMSE: 58.3463
# α=0.0, λ=0.0, depth=5, η=0.01, sub=0.7, col=0.7 → RMSE: 60.3608
# α=0.0, λ=0.0, depth=5, η=0.01, sub=0.7, col=0.8 → RMSE: 60.0929
# α=0.0, λ=0.0, depth=5, η=0.01, sub=0.7, col=0.9 → RMSE: 59.9072
# α=0.0, λ=0.0, depth=5, η=0.01, sub=0.7, col=1.0 → RMSE: 59.7300
# α=0.0, λ=0.0, depth=5, η=0.01, sub=0.8, col=0.7 → RMSE: 60.4753
# α=0.0, λ=0.0, depth=5, η=0.01, sub=0.8, col=0.8 → RMSE: 60.3445
# α=0.0, λ=0.0, depth=5, η=0.01, sub=0.8, col=0.9 → RMSE: 60.1756
# α=0.0, λ=0.0, depth=5, η=0.01, sub=0.8, col=1.0 → RMSE: 60.2543
# α=0.0, λ=0.0, depth=5, η=0.01, sub=0.9, col=0.7 → RMSE: 60.6381
# α=0.0, λ=0.0, depth=5, η=0.01, sub=0.9, col=0.8 → RMSE: 60.3182
# α=0.0, λ=0.0, depth=5, η=0.01, sub=0.9, col=0.9 → RMSE: 60.3110
# α=0.0, λ=0.0, depth=5, η=0.01, sub=0.9, col=1.0 → RMSE: 60.4769
# α=0.0, λ=0.0, depth=5, η=0.01, sub=1.0, col=0.7 → RMSE: 61.2947
# α=0.0, λ=0.0, depth=5, η=0.01, sub=1.0, col=0.8 → RMSE: 61.1319
# α=0.0, λ=0.0, depth=5, η=0.01, sub=1.0, col=0.9 → RMSE: 61.2960
# α=0.0, λ=0.0, depth=5, η=0.01, sub=1.0, col=1.0 → RMSE: 61.3947
# α=0.0, λ=0.0, depth=5, η=0.05, sub=0.7, col=0.7 → RMSE: 56.6372
# α=0.0, λ=0.0, depth=5, η=0.05, sub=0.7, col=0.8 → RMSE: 58.5292
# α=0.0, λ=0.0, depth=5, η=0.05, sub=0.7, col=0.9 → RMSE: 57.2653
# α=0.0, λ=0.0, depth=5, η=0.05, sub=0.7, col=1.0 → RMSE: 57.4911
# α=0.0, λ=0.0, depth=5, η=0.05, sub=0.8, col=0.7 → RMSE: 57.6352
# α=0.0, λ=0.0, depth=5, η=0.05, sub=0.8, col=0.8 → RMSE: 57.8925
# α=0.0, λ=0.0, depth=5, η=0.05, sub=0.8, col=0.9 → RMSE: 57.9207
# α=0.0, λ=0.0, depth=5, η=0.05, sub=0.8, col=1.0 → RMSE: 57.8154
# α=0.0, λ=0.0, depth=5, η=0.05, sub=0.9, col=0.7 → RMSE: 58.2308
# α=0.0, λ=0.0, depth=5, η=0.05, sub=0.9, col=0.8 → RMSE: 57.9763
# α=0.0, λ=0.0, depth=5, η=0.05, sub=0.9, col=0.9 → RMSE: 58.5023
# α=0.0, λ=0.0, depth=5, η=0.05, sub=0.9, col=1.0 → RMSE: 58.9434
# α=0.0, λ=0.0, depth=5, η=0.05, sub=1.0, col=0.7 → RMSE: 58.6238
# α=0.0, λ=0.0, depth=5, η=0.05, sub=1.0, col=0.8 → RMSE: 59.0674
# α=0.0, λ=0.0, depth=5, η=0.05, sub=1.0, col=0.9 → RMSE: 59.0392
# α=0.0, λ=0.0, depth=5, η=0.05, sub=1.0, col=1.0 → RMSE: 59.5700
# α=0.0, λ=0.0, depth=5, η=0.10, sub=0.7, col=0.7 → RMSE: 57.7162
# α=0.0, λ=0.0, depth=5, η=0.10, sub=0.7, col=0.8 → RMSE: 58.7761
# α=0.0, λ=0.0, depth=5, η=0.10, sub=0.7, col=0.9 → RMSE: 58.8098
# α=0.0, λ=0.0, depth=5, η=0.10, sub=0.7, col=1.0 → RMSE: 58.8343
# α=0.0, λ=0.0, depth=5, η=0.10, sub=0.8, col=0.7 → RMSE: 58.1869
# α=0.0, λ=0.0, depth=5, η=0.10, sub=0.8, col=0.8 → RMSE: 58.5068
# α=0.0, λ=0.0, depth=5, η=0.10, sub=0.8, col=0.9 → RMSE: 59.0048
# α=0.0, λ=0.0, depth=5, η=0.10, sub=0.8, col=1.0 → RMSE: 58.9852
# α=0.0, λ=0.0, depth=5, η=0.10, sub=0.9, col=0.7 → RMSE: 59.7146
# α=0.0, λ=0.0, depth=5, η=0.10, sub=0.9, col=0.8 → RMSE: 58.7838
# α=0.0, λ=0.0, depth=5, η=0.10, sub=0.9, col=0.9 → RMSE: 59.7323
# α=0.0, λ=0.0, depth=5, η=0.10, sub=0.9, col=1.0 → RMSE: 59.1716
# α=0.0, λ=0.0, depth=5, η=0.10, sub=1.0, col=0.7 → RMSE: 58.8037
# α=0.0, λ=0.0, depth=5, η=0.10, sub=1.0, col=0.8 → RMSE: 58.9417
# α=0.0, λ=0.0, depth=5, η=0.10, sub=1.0, col=0.9 → RMSE: 59.1237
# α=0.0, λ=0.0, depth=5, η=0.10, sub=1.0, col=1.0 → RMSE: 59.1619
# α=0.0, λ=0.0, depth=5, η=0.20, sub=0.7, col=0.7 → RMSE: 59.7931
# α=0.0, λ=0.0, depth=5, η=0.20, sub=0.7, col=0.8 → RMSE: 58.6718
# α=0.0, λ=0.0, depth=5, η=0.20, sub=0.7, col=0.9 → RMSE: 59.0639
# α=0.0, λ=0.0, depth=5, η=0.20, sub=0.7, col=1.0 → RMSE: 59.2516
# α=0.0, λ=0.0, depth=5, η=0.20, sub=0.8, col=0.7 → RMSE: 60.6948
# α=0.0, λ=0.0, depth=5, η=0.20, sub=0.8, col=0.8 → RMSE: 59.5123
# α=0.0, λ=0.0, depth=5, η=0.20, sub=0.8, col=0.9 → RMSE: 59.2633
# α=0.0, λ=0.0, depth=5, η=0.20, sub=0.8, col=1.0 → RMSE: 59.0987
# α=0.0, λ=0.0, depth=5, η=0.20, sub=0.9, col=0.7 → RMSE: 59.4060
# α=0.0, λ=0.0, depth=5, η=0.20, sub=0.9, col=0.8 → RMSE: 58.4368
# α=0.0, λ=0.0, depth=5, η=0.20, sub=0.9, col=0.9 → RMSE: 60.0247
# α=0.0, λ=0.0, depth=5, η=0.20, sub=0.9, col=1.0 → RMSE: 59.6598
# α=0.0, λ=0.0, depth=5, η=0.20, sub=1.0, col=0.7 → RMSE: 58.1164
# α=0.0, λ=0.0, depth=5, η=0.20, sub=1.0, col=0.8 → RMSE: 60.0723
# α=0.0, λ=0.0, depth=5, η=0.20, sub=1.0, col=0.9 → RMSE: 59.6984
# α=0.0, λ=0.0, depth=5, η=0.20, sub=1.0, col=1.0 → RMSE: 60.2284
# α=0.0, λ=0.0, depth=6, η=0.01, sub=0.7, col=0.7 → RMSE: 60.4182
# α=0.0, λ=0.0, depth=6, η=0.01, sub=0.7, col=0.8 → RMSE: 60.2677
# α=0.0, λ=0.0, depth=6, η=0.01, sub=0.7, col=0.9 → RMSE: 60.0298
# α=0.0, λ=0.0, depth=6, η=0.01, sub=0.7, col=1.0 → RMSE: 60.0032
# α=0.0, λ=0.0, depth=6, η=0.01, sub=0.8, col=0.7 → RMSE: 60.7034
# α=0.0, λ=0.0, depth=6, η=0.01, sub=0.8, col=0.8 → RMSE: 60.4852
# α=0.0, λ=0.0, depth=6, η=0.01, sub=0.8, col=0.9 → RMSE: 60.6427
# α=0.0, λ=0.0, depth=6, η=0.01, sub=0.8, col=1.0 → RMSE: 60.5645
# α=0.0, λ=0.0, depth=6, η=0.01, sub=0.9, col=0.7 → RMSE: 60.8902
# α=0.0, λ=0.0, depth=6, η=0.01, sub=0.9, col=0.8 → RMSE: 60.8530
# α=0.0, λ=0.0, depth=6, η=0.01, sub=0.9, col=0.9 → RMSE: 60.8926
# α=0.0, λ=0.0, depth=6, η=0.01, sub=0.9, col=1.0 → RMSE: 61.0990
# α=0.0, λ=0.0, depth=6, η=0.01, sub=1.0, col=0.7 → RMSE: 61.6685
# α=0.0, λ=0.0, depth=6, η=0.01, sub=1.0, col=0.8 → RMSE: 62.1408
# α=0.0, λ=0.0, depth=6, η=0.01, sub=1.0, col=0.9 → RMSE: 62.2818
# α=0.0, λ=0.0, depth=6, η=0.01, sub=1.0, col=1.0 → RMSE: 62.3419
# α=0.0, λ=0.0, depth=6, η=0.05, sub=0.7, col=0.7 → RMSE: 57.3132
# α=0.0, λ=0.0, depth=6, η=0.05, sub=0.7, col=0.8 → RMSE: 58.7651
# α=0.0, λ=0.0, depth=6, η=0.05, sub=0.7, col=0.9 → RMSE: 58.3792
# α=0.0, λ=0.0, depth=6, η=0.05, sub=0.7, col=1.0 → RMSE: 58.1570
# α=0.0, λ=0.0, depth=6, η=0.05, sub=0.8, col=0.7 → RMSE: 57.9831
# α=0.0, λ=0.0, depth=6, η=0.05, sub=0.8, col=0.8 → RMSE: 59.0638
# α=0.0, λ=0.0, depth=6, η=0.05, sub=0.8, col=0.9 → RMSE: 58.8342
# α=0.0, λ=0.0, depth=6, η=0.05, sub=0.8, col=1.0 → RMSE: 59.3286
# α=0.0, λ=0.0, depth=6, η=0.05, sub=0.9, col=0.7 → RMSE: 58.9656
# α=0.0, λ=0.0, depth=6, η=0.05, sub=0.9, col=0.8 → RMSE: 59.6961
# α=0.0, λ=0.0, depth=6, η=0.05, sub=0.9, col=0.9 → RMSE: 59.4634
# α=0.0, λ=0.0, depth=6, η=0.05, sub=0.9, col=1.0 → RMSE: 60.1525
# α=0.0, λ=0.0, depth=6, η=0.05, sub=1.0, col=0.7 → RMSE: 59.0638
# α=0.0, λ=0.0, depth=6, η=0.05, sub=1.0, col=0.8 → RMSE: 59.5937
# α=0.0, λ=0.0, depth=6, η=0.05, sub=1.0, col=0.9 → RMSE: 61.0541
# α=0.0, λ=0.0, depth=6, η=0.05, sub=1.0, col=1.0 → RMSE: 61.3176
# α=0.0, λ=0.0, depth=6, η=0.10, sub=0.7, col=0.7 → RMSE: 57.9449
# α=0.0, λ=0.0, depth=6, η=0.10, sub=0.7, col=0.8 → RMSE: 58.5201
# α=0.0, λ=0.0, depth=6, η=0.10, sub=0.7, col=0.9 → RMSE: 59.6983
# α=0.0, λ=0.0, depth=6, η=0.10, sub=0.7, col=1.0 → RMSE: 59.3624
# α=0.0, λ=0.0, depth=6, η=0.10, sub=0.8, col=0.7 → RMSE: 57.7981
# α=0.0, λ=0.0, depth=6, η=0.10, sub=0.8, col=0.8 → RMSE: 59.8139
# α=0.0, λ=0.0, depth=6, η=0.10, sub=0.8, col=0.9 → RMSE: 59.4573
# α=0.0, λ=0.0, depth=6, η=0.10, sub=0.8, col=1.0 → RMSE: 59.3551
# α=0.0, λ=0.0, depth=6, η=0.10, sub=0.9, col=0.7 → RMSE: 59.4018
# α=0.0, λ=0.0, depth=6, η=0.10, sub=0.9, col=0.8 → RMSE: 60.1010
# α=0.0, λ=0.0, depth=6, η=0.10, sub=0.9, col=0.9 → RMSE: 60.6823
# α=0.0, λ=0.0, depth=6, η=0.10, sub=0.9, col=1.0 → RMSE: 60.6417
# α=0.0, λ=0.0, depth=6, η=0.10, sub=1.0, col=0.7 → RMSE: 59.6053
# α=0.0, λ=0.0, depth=6, η=0.10, sub=1.0, col=0.8 → RMSE: 61.1310
# α=0.0, λ=0.0, depth=6, η=0.10, sub=1.0, col=0.9 → RMSE: 60.3380
# α=0.0, λ=0.0, depth=6, η=0.10, sub=1.0, col=1.0 → RMSE: 62.2153
# α=0.0, λ=0.0, depth=6, η=0.20, sub=0.7, col=0.7 → RMSE: 60.1873
# α=0.0, λ=0.0, depth=6, η=0.20, sub=0.7, col=0.8 → RMSE: 60.2181
# α=0.0, λ=0.0, depth=6, η=0.20, sub=0.7, col=0.9 → RMSE: 60.0011
# α=0.0, λ=0.0, depth=6, η=0.20, sub=0.7, col=1.0 → RMSE: 61.4122
# α=0.0, λ=0.0, depth=6, η=0.20, sub=0.8, col=0.7 → RMSE: 61.3132
# α=0.0, λ=0.0, depth=6, η=0.20, sub=0.8, col=0.8 → RMSE: 59.7284
# α=0.0, λ=0.0, depth=6, η=0.20, sub=0.8, col=0.9 → RMSE: 60.3211
# α=0.0, λ=0.0, depth=6, η=0.20, sub=0.8, col=1.0 → RMSE: 60.4142
# α=0.0, λ=0.0, depth=6, η=0.20, sub=0.9, col=0.7 → RMSE: 59.6844
# α=0.0, λ=0.0, depth=6, η=0.20, sub=0.9, col=0.8 → RMSE: 60.2675
# α=0.0, λ=0.0, depth=6, η=0.20, sub=0.9, col=0.9 → RMSE: 60.2961
# α=0.0, λ=0.0, depth=6, η=0.20, sub=0.9, col=1.0 → RMSE: 61.1904
# α=0.0, λ=0.0, depth=6, η=0.20, sub=1.0, col=0.7 → RMSE: 59.0699
# α=0.0, λ=0.0, depth=6, η=0.20, sub=1.0, col=0.8 → RMSE: 61.0443
# α=0.0, λ=0.0, depth=6, η=0.20, sub=1.0, col=0.9 → RMSE: 61.8511
# α=0.0, λ=0.0, depth=6, η=0.20, sub=1.0, col=1.0 → RMSE: 61.0662
# α=0.0, λ=0.1, depth=3, η=0.01, sub=0.7, col=0.7 → RMSE: 60.4386
# α=0.0, λ=0.1, depth=3, η=0.01, sub=0.7, col=0.8 → RMSE: 60.3594
# α=0.0, λ=0.1, depth=3, η=0.01, sub=0.7, col=0.9 → RMSE: 60.1174
# α=0.0, λ=0.1, depth=3, η=0.01, sub=0.7, col=1.0 → RMSE: 59.8970
# α=0.0, λ=0.1, depth=3, η=0.01, sub=0.8, col=0.7 → RMSE: 60.5198
# α=0.0, λ=0.1, depth=3, η=0.01, sub=0.8, col=0.8 → RMSE: 60.3300
# α=0.0, λ=0.1, depth=3, η=0.01, sub=0.8, col=0.9 → RMSE: 60.2554
# α=0.0, λ=0.1, depth=3, η=0.01, sub=0.8, col=1.0 → RMSE: 60.1264
# α=0.0, λ=0.1, depth=3, η=0.01, sub=0.9, col=0.7 → RMSE: 60.5503
# α=0.0, λ=0.1, depth=3, η=0.01, sub=0.9, col=0.8 → RMSE: 60.3821
# α=0.0, λ=0.1, depth=3, η=0.01, sub=0.9, col=0.9 → RMSE: 60.1855
# α=0.0, λ=0.1, depth=3, η=0.01, sub=0.9, col=1.0 → RMSE: 60.1605
# α=0.0, λ=0.1, depth=3, η=0.01, sub=1.0, col=0.7 → RMSE: 60.8766
# α=0.0, λ=0.1, depth=3, η=0.01, sub=1.0, col=0.8 → RMSE: 60.6397
# α=0.0, λ=0.1, depth=3, η=0.01, sub=1.0, col=0.9 → RMSE: 60.5368
# α=0.0, λ=0.1, depth=3, η=0.01, sub=1.0, col=1.0 → RMSE: 60.6069
# α=0.0, λ=0.1, depth=3, η=0.05, sub=0.7, col=0.7 → RMSE: 56.1553
# α=0.0, λ=0.1, depth=3, η=0.05, sub=0.7, col=0.8 → RMSE: 56.3209
# α=0.0, λ=0.1, depth=3, η=0.05, sub=0.7, col=0.9 → RMSE: 56.3997
# α=0.0, λ=0.1, depth=3, η=0.05, sub=0.7, col=1.0 → RMSE: 56.4488
# α=0.0, λ=0.1, depth=3, η=0.05, sub=0.8, col=0.7 → RMSE: 56.5523
# α=0.0, λ=0.1, depth=3, η=0.05, sub=0.8, col=0.8 → RMSE: 56.4835
# α=0.0, λ=0.1, depth=3, η=0.05, sub=0.8, col=0.9 → RMSE: 56.5598
# α=0.0, λ=0.1, depth=3, η=0.05, sub=0.8, col=1.0 → RMSE: 56.7419
# α=0.0, λ=0.1, depth=3, η=0.05, sub=0.9, col=0.7 → RMSE: 56.3968
# α=0.0, λ=0.1, depth=3, η=0.05, sub=0.9, col=0.8 → RMSE: 56.5696
# α=0.0, λ=0.1, depth=3, η=0.05, sub=0.9, col=0.9 → RMSE: 56.2102
# α=0.0, λ=0.1, depth=3, η=0.05, sub=0.9, col=1.0 → RMSE: 56.4429
# α=0.0, λ=0.1, depth=3, η=0.05, sub=1.0, col=0.7 → RMSE: 56.2103
# α=0.0, λ=0.1, depth=3, η=0.05, sub=1.0, col=0.8 → RMSE: 56.4818
# α=0.0, λ=0.1, depth=3, η=0.05, sub=1.0, col=0.9 → RMSE: 56.6124
# α=0.0, λ=0.1, depth=3, η=0.05, sub=1.0, col=1.0 → RMSE: 56.8562
# α=0.0, λ=0.1, depth=3, η=0.10, sub=0.7, col=0.7 → RMSE: 55.5857
# α=0.0, λ=0.1, depth=3, η=0.10, sub=0.7, col=0.8 → RMSE: 56.4125
# α=0.0, λ=0.1, depth=3, η=0.10, sub=0.7, col=0.9 → RMSE: 55.7156
# α=0.0, λ=0.1, depth=3, η=0.10, sub=0.7, col=1.0 → RMSE: 56.1311
# α=0.0, λ=0.1, depth=3, η=0.10, sub=0.8, col=0.7 → RMSE: 56.3733
# α=0.0, λ=0.1, depth=3, η=0.10, sub=0.8, col=0.8 → RMSE: 56.0712
# α=0.0, λ=0.1, depth=3, η=0.10, sub=0.8, col=0.9 → RMSE: 56.6655
# α=0.0, λ=0.1, depth=3, η=0.10, sub=0.8, col=1.0 → RMSE: 56.5159
# α=0.0, λ=0.1, depth=3, η=0.10, sub=0.9, col=0.7 → RMSE: 56.6489
# α=0.0, λ=0.1, depth=3, η=0.10, sub=0.9, col=0.8 → RMSE: 56.6059
# α=0.0, λ=0.1, depth=3, η=0.10, sub=0.9, col=0.9 → RMSE: 56.2458
# α=0.0, λ=0.1, depth=3, η=0.10, sub=0.9, col=1.0 → RMSE: 56.2755
# α=0.0, λ=0.1, depth=3, η=0.10, sub=1.0, col=0.7 → RMSE: 56.4657
# α=0.0, λ=0.1, depth=3, η=0.10, sub=1.0, col=0.8 → RMSE: 56.9285
# α=0.0, λ=0.1, depth=3, η=0.10, sub=1.0, col=0.9 → RMSE: 56.6139
# α=0.0, λ=0.1, depth=3, η=0.10, sub=1.0, col=1.0 → RMSE: 56.5376
# α=0.0, λ=0.1, depth=3, η=0.20, sub=0.7, col=0.7 → RMSE: 55.8928
# α=0.0, λ=0.1, depth=3, η=0.20, sub=0.7, col=0.8 → RMSE: 57.1350
# α=0.0, λ=0.1, depth=3, η=0.20, sub=0.7, col=0.9 → RMSE: 57.1816
# α=0.0, λ=0.1, depth=3, η=0.20, sub=0.7, col=1.0 → RMSE: 57.0773
# α=0.0, λ=0.1, depth=3, η=0.20, sub=0.8, col=0.7 → RMSE: 56.4551
# α=0.0, λ=0.1, depth=3, η=0.20, sub=0.8, col=0.8 → RMSE: 56.5757
# α=0.0, λ=0.1, depth=3, η=0.20, sub=0.8, col=0.9 → RMSE: 56.6945
# α=0.0, λ=0.1, depth=3, η=0.20, sub=0.8, col=1.0 → RMSE: 56.5645
# α=0.0, λ=0.1, depth=3, η=0.20, sub=0.9, col=0.7 → RMSE: 56.2559
# α=0.0, λ=0.1, depth=3, η=0.20, sub=0.9, col=0.8 → RMSE: 56.7973
# α=0.0, λ=0.1, depth=3, η=0.20, sub=0.9, col=0.9 → RMSE: 57.1307
# α=0.0, λ=0.1, depth=3, η=0.20, sub=0.9, col=1.0 → RMSE: 56.1143
# α=0.0, λ=0.1, depth=3, η=0.20, sub=1.0, col=0.7 → RMSE: 56.8873
# α=0.0, λ=0.1, depth=3, η=0.20, sub=1.0, col=0.8 → RMSE: 56.6128
# α=0.0, λ=0.1, depth=3, η=0.20, sub=1.0, col=0.9 → RMSE: 56.4539
# α=0.0, λ=0.1, depth=3, η=0.20, sub=1.0, col=1.0 → RMSE: 57.4999
# α=0.0, λ=0.1, depth=4, η=0.01, sub=0.7, col=0.7 → RMSE: 60.4489
# α=0.0, λ=0.1, depth=4, η=0.01, sub=0.7, col=0.8 → RMSE: 60.2251
# α=0.0, λ=0.1, depth=4, η=0.01, sub=0.7, col=0.9 → RMSE: 60.0296
# α=0.0, λ=0.1, depth=4, η=0.01, sub=0.7, col=1.0 → RMSE: 59.8789
# α=0.0, λ=0.1, depth=4, η=0.01, sub=0.8, col=0.7 → RMSE: 60.4823
# α=0.0, λ=0.1, depth=4, η=0.01, sub=0.8, col=0.8 → RMSE: 60.1609
# α=0.0, λ=0.1, depth=4, η=0.01, sub=0.8, col=0.9 → RMSE: 60.0825
# α=0.0, λ=0.1, depth=4, η=0.01, sub=0.8, col=1.0 → RMSE: 60.1069
# α=0.0, λ=0.1, depth=4, η=0.01, sub=0.9, col=0.7 → RMSE: 60.5881
# α=0.0, λ=0.1, depth=4, η=0.01, sub=0.9, col=0.8 → RMSE: 60.2969
# α=0.0, λ=0.1, depth=4, η=0.01, sub=0.9, col=0.9 → RMSE: 60.1436
# α=0.0, λ=0.1, depth=4, η=0.01, sub=0.9, col=1.0 → RMSE: 60.2553
# α=0.0, λ=0.1, depth=4, η=0.01, sub=1.0, col=0.7 → RMSE: 60.9792
# α=0.0, λ=0.1, depth=4, η=0.01, sub=1.0, col=0.8 → RMSE: 60.8019
# α=0.0, λ=0.1, depth=4, η=0.01, sub=1.0, col=0.9 → RMSE: 60.5274
# α=0.0, λ=0.1, depth=4, η=0.01, sub=1.0, col=1.0 → RMSE: 60.6306
# α=0.0, λ=0.1, depth=4, η=0.05, sub=0.7, col=0.7 → RMSE: 56.6029
# α=0.0, λ=0.1, depth=4, η=0.05, sub=0.7, col=0.8 → RMSE: 57.5813
# α=0.0, λ=0.1, depth=4, η=0.05, sub=0.7, col=0.9 → RMSE: 56.9078
# α=0.0, λ=0.1, depth=4, η=0.05, sub=0.7, col=1.0 → RMSE: 57.4838
# α=0.0, λ=0.1, depth=4, η=0.05, sub=0.8, col=0.7 → RMSE: 56.8781
# α=0.0, λ=0.1, depth=4, η=0.05, sub=0.8, col=0.8 → RMSE: 56.6958
# α=0.0, λ=0.1, depth=4, η=0.05, sub=0.8, col=0.9 → RMSE: 57.0735
# α=0.0, λ=0.1, depth=4, η=0.05, sub=0.8, col=1.0 → RMSE: 57.3764
# α=0.0, λ=0.1, depth=4, η=0.05, sub=0.9, col=0.7 → RMSE: 58.0187
# α=0.0, λ=0.1, depth=4, η=0.05, sub=0.9, col=0.8 → RMSE: 57.8607
# α=0.0, λ=0.1, depth=4, η=0.05, sub=0.9, col=0.9 → RMSE: 57.4479
# α=0.0, λ=0.1, depth=4, η=0.05, sub=0.9, col=1.0 → RMSE: 57.6550
# α=0.0, λ=0.1, depth=4, η=0.05, sub=1.0, col=0.7 → RMSE: 57.8069
# α=0.0, λ=0.1, depth=4, η=0.05, sub=1.0, col=0.8 → RMSE: 57.3088
# α=0.0, λ=0.1, depth=4, η=0.05, sub=1.0, col=0.9 → RMSE: 57.9813
# α=0.0, λ=0.1, depth=4, η=0.05, sub=1.0, col=1.0 → RMSE: 57.7894
# α=0.0, λ=0.1, depth=4, η=0.10, sub=0.7, col=0.7 → RMSE: 56.7691
# α=0.0, λ=0.1, depth=4, η=0.10, sub=0.7, col=0.8 → RMSE: 57.8575
# α=0.0, λ=0.1, depth=4, η=0.10, sub=0.7, col=0.9 → RMSE: 56.6961
# α=0.0, λ=0.1, depth=4, η=0.10, sub=0.7, col=1.0 → RMSE: 57.1616
# α=0.0, λ=0.1, depth=4, η=0.10, sub=0.8, col=0.7 → RMSE: 57.5846
# α=0.0, λ=0.1, depth=4, η=0.10, sub=0.8, col=0.8 → RMSE: 57.3042
# α=0.0, λ=0.1, depth=4, η=0.10, sub=0.8, col=0.9 → RMSE: 57.0644
# α=0.0, λ=0.1, depth=4, η=0.10, sub=0.8, col=1.0 → RMSE: 58.2831
# α=0.0, λ=0.1, depth=4, η=0.10, sub=0.9, col=0.7 → RMSE: 57.9545
# α=0.0, λ=0.1, depth=4, η=0.10, sub=0.9, col=0.8 → RMSE: 57.1524
# α=0.0, λ=0.1, depth=4, η=0.10, sub=0.9, col=0.9 → RMSE: 57.9146
# α=0.0, λ=0.1, depth=4, η=0.10, sub=0.9, col=1.0 → RMSE: 57.7296
# α=0.0, λ=0.1, depth=4, η=0.10, sub=1.0, col=0.7 → RMSE: 57.6526
# α=0.0, λ=0.1, depth=4, η=0.10, sub=1.0, col=0.8 → RMSE: 58.1811
# α=0.0, λ=0.1, depth=4, η=0.10, sub=1.0, col=0.9 → RMSE: 57.6983
# α=0.0, λ=0.1, depth=4, η=0.10, sub=1.0, col=1.0 → RMSE: 58.3886
# α=0.0, λ=0.1, depth=4, η=0.20, sub=0.7, col=0.7 → RMSE: 58.1668
# α=0.0, λ=0.1, depth=4, η=0.20, sub=0.7, col=0.8 → RMSE: 56.9019
# α=0.0, λ=0.1, depth=4, η=0.20, sub=0.7, col=0.9 → RMSE: 58.1025
# α=0.0, λ=0.1, depth=4, η=0.20, sub=0.7, col=1.0 → RMSE: 57.0979
# α=0.0, λ=0.1, depth=4, η=0.20, sub=0.8, col=0.7 → RMSE: 57.2030
# α=0.0, λ=0.1, depth=4, η=0.20, sub=0.8, col=0.8 → RMSE: 58.8819
# α=0.0, λ=0.1, depth=4, η=0.20, sub=0.8, col=0.9 → RMSE: 58.1020
# α=0.0, λ=0.1, depth=4, η=0.20, sub=0.8, col=1.0 → RMSE: 57.7221
# α=0.0, λ=0.1, depth=4, η=0.20, sub=0.9, col=0.7 → RMSE: 58.7940
# α=0.0, λ=0.1, depth=4, η=0.20, sub=0.9, col=0.8 → RMSE: 58.6491
# α=0.0, λ=0.1, depth=4, η=0.20, sub=0.9, col=0.9 → RMSE: 58.9573
# α=0.0, λ=0.1, depth=4, η=0.20, sub=0.9, col=1.0 → RMSE: 58.6357
# α=0.0, λ=0.1, depth=4, η=0.20, sub=1.0, col=0.7 → RMSE: 57.1331
# α=0.0, λ=0.1, depth=4, η=0.20, sub=1.0, col=0.8 → RMSE: 58.8219
# α=0.0, λ=0.1, depth=4, η=0.20, sub=1.0, col=0.9 → RMSE: 58.0679
# α=0.0, λ=0.1, depth=4, η=0.20, sub=1.0, col=1.0 → RMSE: 58.6791
# α=0.0, λ=0.1, depth=5, η=0.01, sub=0.7, col=0.7 → RMSE: 60.5181
# α=0.0, λ=0.1, depth=5, η=0.01, sub=0.7, col=0.8 → RMSE: 60.1866
# α=0.0, λ=0.1, depth=5, η=0.01, sub=0.7, col=0.9 → RMSE: 60.0324
# α=0.0, λ=0.1, depth=5, η=0.01, sub=0.7, col=1.0 → RMSE: 59.7257
# α=0.0, λ=0.1, depth=5, η=0.01, sub=0.8, col=0.7 → RMSE: 60.5738
# α=0.0, λ=0.1, depth=5, η=0.01, sub=0.8, col=0.8 → RMSE: 60.3315
# α=0.0, λ=0.1, depth=5, η=0.01, sub=0.8, col=0.9 → RMSE: 60.2527
# α=0.0, λ=0.1, depth=5, η=0.01, sub=0.8, col=1.0 → RMSE: 60.3529
# α=0.0, λ=0.1, depth=5, η=0.01, sub=0.9, col=0.7 → RMSE: 60.6325
# α=0.0, λ=0.1, depth=5, η=0.01, sub=0.9, col=0.8 → RMSE: 60.3266
# α=0.0, λ=0.1, depth=5, η=0.01, sub=0.9, col=0.9 → RMSE: 60.3887
# α=0.0, λ=0.1, depth=5, η=0.01, sub=0.9, col=1.0 → RMSE: 60.4129
# α=0.0, λ=0.1, depth=5, η=0.01, sub=1.0, col=0.7 → RMSE: 61.1985
# α=0.0, λ=0.1, depth=5, η=0.01, sub=1.0, col=0.8 → RMSE: 61.1036
# α=0.0, λ=0.1, depth=5, η=0.01, sub=1.0, col=0.9 → RMSE: 61.1350
# α=0.0, λ=0.1, depth=5, η=0.01, sub=1.0, col=1.0 → RMSE: 61.1390
# α=0.0, λ=0.1, depth=5, η=0.05, sub=0.7, col=0.7 → RMSE: 56.8429
# α=0.0, λ=0.1, depth=5, η=0.05, sub=0.7, col=0.8 → RMSE: 58.1050
# α=0.0, λ=0.1, depth=5, η=0.05, sub=0.7, col=0.9 → RMSE: 57.3946
# α=0.0, λ=0.1, depth=5, η=0.05, sub=0.7, col=1.0 → RMSE: 57.9056
# α=0.0, λ=0.1, depth=5, η=0.05, sub=0.8, col=0.7 → RMSE: 57.5353
# α=0.0, λ=0.1, depth=5, η=0.05, sub=0.8, col=0.8 → RMSE: 57.8993
# α=0.0, λ=0.1, depth=5, η=0.05, sub=0.8, col=0.9 → RMSE: 58.0284
# α=0.0, λ=0.1, depth=5, η=0.05, sub=0.8, col=1.0 → RMSE: 58.1237
# α=0.0, λ=0.1, depth=5, η=0.05, sub=0.9, col=0.7 → RMSE: 58.2963
# α=0.0, λ=0.1, depth=5, η=0.05, sub=0.9, col=0.8 → RMSE: 57.8171
# α=0.0, λ=0.1, depth=5, η=0.05, sub=0.9, col=0.9 → RMSE: 58.2491
# α=0.0, λ=0.1, depth=5, η=0.05, sub=0.9, col=1.0 → RMSE: 58.6462
# α=0.0, λ=0.1, depth=5, η=0.05, sub=1.0, col=0.7 → RMSE: 58.3034
# α=0.0, λ=0.1, depth=5, η=0.05, sub=1.0, col=0.8 → RMSE: 58.6500
# α=0.0, λ=0.1, depth=5, η=0.05, sub=1.0, col=0.9 → RMSE: 58.9373
# α=0.0, λ=0.1, depth=5, η=0.05, sub=1.0, col=1.0 → RMSE: 59.5383
# α=0.0, λ=0.1, depth=5, η=0.10, sub=0.7, col=0.7 → RMSE: 57.3129
# α=0.0, λ=0.1, depth=5, η=0.10, sub=0.7, col=0.8 → RMSE: 58.0597
# α=0.0, λ=0.1, depth=5, η=0.10, sub=0.7, col=0.9 → RMSE: 58.4588
# α=0.0, λ=0.1, depth=5, η=0.10, sub=0.7, col=1.0 → RMSE: 57.9913
# α=0.0, λ=0.1, depth=5, η=0.10, sub=0.8, col=0.7 → RMSE: 57.8220
# α=0.0, λ=0.1, depth=5, η=0.10, sub=0.8, col=0.8 → RMSE: 58.3984
# α=0.0, λ=0.1, depth=5, η=0.10, sub=0.8, col=0.9 → RMSE: 58.0128
# α=0.0, λ=0.1, depth=5, η=0.10, sub=0.8, col=1.0 → RMSE: 58.7540
# α=0.0, λ=0.1, depth=5, η=0.10, sub=0.9, col=0.7 → RMSE: 59.2477
# α=0.0, λ=0.1, depth=5, η=0.10, sub=0.9, col=0.8 → RMSE: 58.6263
# α=0.0, λ=0.1, depth=5, η=0.10, sub=0.9, col=0.9 → RMSE: 59.2646
# α=0.0, λ=0.1, depth=5, η=0.10, sub=0.9, col=1.0 → RMSE: 59.3872
# α=0.0, λ=0.1, depth=5, η=0.10, sub=1.0, col=0.7 → RMSE: 58.1314
# α=0.0, λ=0.1, depth=5, η=0.10, sub=1.0, col=0.8 → RMSE: 59.0189
# α=0.0, λ=0.1, depth=5, η=0.10, sub=1.0, col=0.9 → RMSE: 58.8282
# α=0.0, λ=0.1, depth=5, η=0.10, sub=1.0, col=1.0 → RMSE: 59.9352
# α=0.0, λ=0.1, depth=5, η=0.20, sub=0.7, col=0.7 → RMSE: 58.5650
# α=0.0, λ=0.1, depth=5, η=0.20, sub=0.7, col=0.8 → RMSE: 59.4639
# α=0.0, λ=0.1, depth=5, η=0.20, sub=0.7, col=0.9 → RMSE: 59.0964
# α=0.0, λ=0.1, depth=5, η=0.20, sub=0.7, col=1.0 → RMSE: 58.0395
# α=0.0, λ=0.1, depth=5, η=0.20, sub=0.8, col=0.7 → RMSE: 59.3840
# α=0.0, λ=0.1, depth=5, η=0.20, sub=0.8, col=0.8 → RMSE: 60.0010
# α=0.0, λ=0.1, depth=5, η=0.20, sub=0.8, col=0.9 → RMSE: 59.8706
# α=0.0, λ=0.1, depth=5, η=0.20, sub=0.8, col=1.0 → RMSE: 58.2993
# α=0.0, λ=0.1, depth=5, η=0.20, sub=0.9, col=0.7 → RMSE: 59.6529
# α=0.0, λ=0.1, depth=5, η=0.20, sub=0.9, col=0.8 → RMSE: 58.6203
# α=0.0, λ=0.1, depth=5, η=0.20, sub=0.9, col=0.9 → RMSE: 59.2396
# α=0.0, λ=0.1, depth=5, η=0.20, sub=0.9, col=1.0 → RMSE: 60.1469
# α=0.0, λ=0.1, depth=5, η=0.20, sub=1.0, col=0.7 → RMSE: 58.3049
# α=0.0, λ=0.1, depth=5, η=0.20, sub=1.0, col=0.8 → RMSE: 59.6476
# α=0.0, λ=0.1, depth=5, η=0.20, sub=1.0, col=0.9 → RMSE: 60.3019
# α=0.0, λ=0.1, depth=5, η=0.20, sub=1.0, col=1.0 → RMSE: 60.7021
# α=0.0, λ=0.1, depth=6, η=0.01, sub=0.7, col=0.7 → RMSE: 60.6118
# α=0.0, λ=0.1, depth=6, η=0.01, sub=0.7, col=0.8 → RMSE: 60.4260
# α=0.0, λ=0.1, depth=6, η=0.01, sub=0.7, col=0.9 → RMSE: 60.3478
# α=0.0, λ=0.1, depth=6, η=0.01, sub=0.7, col=1.0 → RMSE: 60.0237
# α=0.0, λ=0.1, depth=6, η=0.01, sub=0.8, col=0.7 → RMSE: 60.8338
# α=0.0, λ=0.1, depth=6, η=0.01, sub=0.8, col=0.8 → RMSE: 60.5426
# α=0.0, λ=0.1, depth=6, η=0.01, sub=0.8, col=0.9 → RMSE: 60.8450
# α=0.0, λ=0.1, depth=6, η=0.01, sub=0.8, col=1.0 → RMSE: 60.7537
# α=0.0, λ=0.1, depth=6, η=0.01, sub=0.9, col=0.7 → RMSE: 60.9384
# α=0.0, λ=0.1, depth=6, η=0.01, sub=0.9, col=0.8 → RMSE: 60.9624
# α=0.0, λ=0.1, depth=6, η=0.01, sub=0.9, col=0.9 → RMSE: 60.9323
# α=0.0, λ=0.1, depth=6, η=0.01, sub=0.9, col=1.0 → RMSE: 61.1306
# α=0.0, λ=0.1, depth=6, η=0.01, sub=1.0, col=0.7 → RMSE: 61.6552
# α=0.0, λ=0.1, depth=6, η=0.01, sub=1.0, col=0.8 → RMSE: 61.8619
# α=0.0, λ=0.1, depth=6, η=0.01, sub=1.0, col=0.9 → RMSE: 61.9847
# α=0.0, λ=0.1, depth=6, η=0.01, sub=1.0, col=1.0 → RMSE: 61.8139
# α=0.0, λ=0.1, depth=6, η=0.05, sub=0.7, col=0.7 → RMSE: 57.3766
# α=0.0, λ=0.1, depth=6, η=0.05, sub=0.7, col=0.8 → RMSE: 58.8469
# α=0.0, λ=0.1, depth=6, η=0.05, sub=0.7, col=0.9 → RMSE: 58.3495
# α=0.0, λ=0.1, depth=6, η=0.05, sub=0.7, col=1.0 → RMSE: 58.6007
# α=0.0, λ=0.1, depth=6, η=0.05, sub=0.8, col=0.7 → RMSE: 58.1483
# α=0.0, λ=0.1, depth=6, η=0.05, sub=0.8, col=0.8 → RMSE: 58.3722
# α=0.0, λ=0.1, depth=6, η=0.05, sub=0.8, col=0.9 → RMSE: 58.9108
# α=0.0, λ=0.1, depth=6, η=0.05, sub=0.8, col=1.0 → RMSE: 59.3222
# α=0.0, λ=0.1, depth=6, η=0.05, sub=0.9, col=0.7 → RMSE: 59.1006
# α=0.0, λ=0.1, depth=6, η=0.05, sub=0.9, col=0.8 → RMSE: 59.1024
# α=0.0, λ=0.1, depth=6, η=0.05, sub=0.9, col=0.9 → RMSE: 59.4554
# α=0.0, λ=0.1, depth=6, η=0.05, sub=0.9, col=1.0 → RMSE: 59.8786
# α=0.0, λ=0.1, depth=6, η=0.05, sub=1.0, col=0.7 → RMSE: 59.2260
# α=0.0, λ=0.1, depth=6, η=0.05, sub=1.0, col=0.8 → RMSE: 60.2595
# α=0.0, λ=0.1, depth=6, η=0.05, sub=1.0, col=0.9 → RMSE: 60.3129
# α=0.0, λ=0.1, depth=6, η=0.05, sub=1.0, col=1.0 → RMSE: 60.2791
# α=0.0, λ=0.1, depth=6, η=0.10, sub=0.7, col=0.7 → RMSE: 58.2665
# α=0.0, λ=0.1, depth=6, η=0.10, sub=0.7, col=0.8 → RMSE: 58.7354
# α=0.0, λ=0.1, depth=6, η=0.10, sub=0.7, col=0.9 → RMSE: 58.6048
# α=0.0, λ=0.1, depth=6, η=0.10, sub=0.7, col=1.0 → RMSE: 58.6417
# α=0.0, λ=0.1, depth=6, η=0.10, sub=0.8, col=0.7 → RMSE: 57.7752
# α=0.0, λ=0.1, depth=6, η=0.10, sub=0.8, col=0.8 → RMSE: 59.2698
# α=0.0, λ=0.1, depth=6, η=0.10, sub=0.8, col=0.9 → RMSE: 60.0676
# α=0.0, λ=0.1, depth=6, η=0.10, sub=0.8, col=1.0 → RMSE: 59.6091
# α=0.0, λ=0.1, depth=6, η=0.10, sub=0.9, col=0.7 → RMSE: 59.4855
# α=0.0, λ=0.1, depth=6, η=0.10, sub=0.9, col=0.8 → RMSE: 59.7113
# α=0.0, λ=0.1, depth=6, η=0.10, sub=0.9, col=0.9 → RMSE: 59.7287
# α=0.0, λ=0.1, depth=6, η=0.10, sub=0.9, col=1.0 → RMSE: 60.2319
# α=0.0, λ=0.1, depth=6, η=0.10, sub=1.0, col=0.7 → RMSE: 59.1291
# α=0.0, λ=0.1, depth=6, η=0.10, sub=1.0, col=0.8 → RMSE: 59.9541
# α=0.0, λ=0.1, depth=6, η=0.10, sub=1.0, col=0.9 → RMSE: 60.7472
# α=0.0, λ=0.1, depth=6, η=0.10, sub=1.0, col=1.0 → RMSE: 60.3561
# α=0.0, λ=0.1, depth=6, η=0.20, sub=0.7, col=0.7 → RMSE: 59.1476
# α=0.0, λ=0.1, depth=6, η=0.20, sub=0.7, col=0.8 → RMSE: 60.9348
# α=0.0, λ=0.1, depth=6, η=0.20, sub=0.7, col=0.9 → RMSE: 60.9550
# α=0.0, λ=0.1, depth=6, η=0.20, sub=0.7, col=1.0 → RMSE: 60.0675
# α=0.0, λ=0.1, depth=6, η=0.20, sub=0.8, col=0.7 → RMSE: 60.5335
# α=0.0, λ=0.1, depth=6, η=0.20, sub=0.8, col=0.8 → RMSE: 61.0889
# α=0.0, λ=0.1, depth=6, η=0.20, sub=0.8, col=0.9 → RMSE: 60.7418
# α=0.0, λ=0.1, depth=6, η=0.20, sub=0.8, col=1.0 → RMSE: 60.3910
# α=0.0, λ=0.1, depth=6, η=0.20, sub=0.9, col=0.7 → RMSE: 60.0528
# α=0.0, λ=0.1, depth=6, η=0.20, sub=0.9, col=0.8 → RMSE: 61.2251
# α=0.0, λ=0.1, depth=6, η=0.20, sub=0.9, col=0.9 → RMSE: 60.5246
# α=0.0, λ=0.1, depth=6, η=0.20, sub=0.9, col=1.0 → RMSE: 60.6253
# α=0.0, λ=0.1, depth=6, η=0.20, sub=1.0, col=0.7 → RMSE: 59.6310
# α=0.0, λ=0.1, depth=6, η=0.20, sub=1.0, col=0.8 → RMSE: 60.6904
# α=0.0, λ=0.1, depth=6, η=0.20, sub=1.0, col=0.9 → RMSE: 61.3161
# α=0.0, λ=0.1, depth=6, η=0.20, sub=1.0, col=1.0 → RMSE: 60.6106
# α=0.0, λ=0.3, depth=3, η=0.01, sub=0.7, col=0.7 → RMSE: 60.4846
# α=0.0, λ=0.3, depth=3, η=0.01, sub=0.7, col=0.8 → RMSE: 60.3764
# α=0.0, λ=0.3, depth=3, η=0.01, sub=0.7, col=0.9 → RMSE: 60.1078
# α=0.0, λ=0.3, depth=3, η=0.01, sub=0.7, col=1.0 → RMSE: 60.0098
# α=0.0, λ=0.3, depth=3, η=0.01, sub=0.8, col=0.7 → RMSE: 60.5084
# α=0.0, λ=0.3, depth=3, η=0.01, sub=0.8, col=0.8 → RMSE: 60.3525
# α=0.0, λ=0.3, depth=3, η=0.01, sub=0.8, col=0.9 → RMSE: 60.2720
# α=0.0, λ=0.3, depth=3, η=0.01, sub=0.8, col=1.0 → RMSE: 60.1944
# α=0.0, λ=0.3, depth=3, η=0.01, sub=0.9, col=0.7 → RMSE: 60.5599
# α=0.0, λ=0.3, depth=3, η=0.01, sub=0.9, col=0.8 → RMSE: 60.3913
# α=0.0, λ=0.3, depth=3, η=0.01, sub=0.9, col=0.9 → RMSE: 60.1717
# α=0.0, λ=0.3, depth=3, η=0.01, sub=0.9, col=1.0 → RMSE: 60.2211
# α=0.0, λ=0.3, depth=3, η=0.01, sub=1.0, col=0.7 → RMSE: 60.7802
# α=0.0, λ=0.3, depth=3, η=0.01, sub=1.0, col=0.8 → RMSE: 60.6421
# α=0.0, λ=0.3, depth=3, η=0.01, sub=1.0, col=0.9 → RMSE: 60.5868
# α=0.0, λ=0.3, depth=3, η=0.01, sub=1.0, col=1.0 → RMSE: 60.6339
# α=0.0, λ=0.3, depth=3, η=0.05, sub=0.7, col=0.7 → RMSE: 56.3061
# α=0.0, λ=0.3, depth=3, η=0.05, sub=0.7, col=0.8 → RMSE: 56.3866
# α=0.0, λ=0.3, depth=3, η=0.05, sub=0.7, col=0.9 → RMSE: 56.4603
# α=0.0, λ=0.3, depth=3, η=0.05, sub=0.7, col=1.0 → RMSE: 56.4647
# α=0.0, λ=0.3, depth=3, η=0.05, sub=0.8, col=0.7 → RMSE: 56.4809
# α=0.0, λ=0.3, depth=3, η=0.05, sub=0.8, col=0.8 → RMSE: 56.4145
# α=0.0, λ=0.3, depth=3, η=0.05, sub=0.8, col=0.9 → RMSE: 56.3292
# α=0.0, λ=0.3, depth=3, η=0.05, sub=0.8, col=1.0 → RMSE: 56.5444
# α=0.0, λ=0.3, depth=3, η=0.05, sub=0.9, col=0.7 → RMSE: 56.4081
# α=0.0, λ=0.3, depth=3, η=0.05, sub=0.9, col=0.8 → RMSE: 56.3475
# α=0.0, λ=0.3, depth=3, η=0.05, sub=0.9, col=0.9 → RMSE: 56.5168
# α=0.0, λ=0.3, depth=3, η=0.05, sub=0.9, col=1.0 → RMSE: 56.5257
# α=0.0, λ=0.3, depth=3, η=0.05, sub=1.0, col=0.7 → RMSE: 56.2862
# α=0.0, λ=0.3, depth=3, η=0.05, sub=1.0, col=0.8 → RMSE: 56.5175
# α=0.0, λ=0.3, depth=3, η=0.05, sub=1.0, col=0.9 → RMSE: 56.5101
# α=0.0, λ=0.3, depth=3, η=0.05, sub=1.0, col=1.0 → RMSE: 56.5784
# α=0.0, λ=0.3, depth=3, η=0.10, sub=0.7, col=0.7 → RMSE: 55.4340
# α=0.0, λ=0.3, depth=3, η=0.10, sub=0.7, col=0.8 → RMSE: 56.0594
# α=0.0, λ=0.3, depth=3, η=0.10, sub=0.7, col=0.9 → RMSE: 55.7782
# α=0.0, λ=0.3, depth=3, η=0.10, sub=0.7, col=1.0 → RMSE: 55.7520
# α=0.0, λ=0.3, depth=3, η=0.10, sub=0.8, col=0.7 → RMSE: 56.4543
# α=0.0, λ=0.3, depth=3, η=0.10, sub=0.8, col=0.8 → RMSE: 56.1857
# α=0.0, λ=0.3, depth=3, η=0.10, sub=0.8, col=0.9 → RMSE: 56.2586
# α=0.0, λ=0.3, depth=3, η=0.10, sub=0.8, col=1.0 → RMSE: 56.2388
# α=0.0, λ=0.3, depth=3, η=0.10, sub=0.9, col=0.7 → RMSE: 56.1677
# α=0.0, λ=0.3, depth=3, η=0.10, sub=0.9, col=0.8 → RMSE: 56.5482
# α=0.0, λ=0.3, depth=3, η=0.10, sub=0.9, col=0.9 → RMSE: 56.5984
# α=0.0, λ=0.3, depth=3, η=0.10, sub=0.9, col=1.0 → RMSE: 56.2971
# α=0.0, λ=0.3, depth=3, η=0.10, sub=1.0, col=0.7 → RMSE: 56.6083
# α=0.0, λ=0.3, depth=3, η=0.10, sub=1.0, col=0.8 → RMSE: 56.2425
# α=0.0, λ=0.3, depth=3, η=0.10, sub=1.0, col=0.9 → RMSE: 56.5049
# α=0.0, λ=0.3, depth=3, η=0.10, sub=1.0, col=1.0 → RMSE: 56.6301
# α=0.0, λ=0.3, depth=3, η=0.20, sub=0.7, col=0.7 → RMSE: 56.0230
# α=0.0, λ=0.3, depth=3, η=0.20, sub=0.7, col=0.8 → RMSE: 56.8822
# α=0.0, λ=0.3, depth=3, η=0.20, sub=0.7, col=0.9 → RMSE: 57.0620
# α=0.0, λ=0.3, depth=3, η=0.20, sub=0.7, col=1.0 → RMSE: 56.7313
# α=0.0, λ=0.3, depth=3, η=0.20, sub=0.8, col=0.7 → RMSE: 55.9951
# α=0.0, λ=0.3, depth=3, η=0.20, sub=0.8, col=0.8 → RMSE: 56.2222
# α=0.0, λ=0.3, depth=3, η=0.20, sub=0.8, col=0.9 → RMSE: 57.2514
# α=0.0, λ=0.3, depth=3, η=0.20, sub=0.8, col=1.0 → RMSE: 56.3731
# α=0.0, λ=0.3, depth=3, η=0.20, sub=0.9, col=0.7 → RMSE: 56.8190
# α=0.0, λ=0.3, depth=3, η=0.20, sub=0.9, col=0.8 → RMSE: 57.0474
# α=0.0, λ=0.3, depth=3, η=0.20, sub=0.9, col=0.9 → RMSE: 56.8770
# α=0.0, λ=0.3, depth=3, η=0.20, sub=0.9, col=1.0 → RMSE: 56.0566
# α=0.0, λ=0.3, depth=3, η=0.20, sub=1.0, col=0.7 → RMSE: 56.4094
# α=0.0, λ=0.3, depth=3, η=0.20, sub=1.0, col=0.8 → RMSE: 56.3274
# α=0.0, λ=0.3, depth=3, η=0.20, sub=1.0, col=0.9 → RMSE: 56.7215
# α=0.0, λ=0.3, depth=3, η=0.20, sub=1.0, col=1.0 → RMSE: 57.2157
# α=0.0, λ=0.3, depth=4, η=0.01, sub=0.7, col=0.7 → RMSE: 60.4607
# α=0.0, λ=0.3, depth=4, η=0.01, sub=0.7, col=0.8 → RMSE: 60.2684
# α=0.0, λ=0.3, depth=4, η=0.01, sub=0.7, col=0.9 → RMSE: 60.0713
# α=0.0, λ=0.3, depth=4, η=0.01, sub=0.7, col=1.0 → RMSE: 59.8968
# α=0.0, λ=0.3, depth=4, η=0.01, sub=0.8, col=0.7 → RMSE: 60.5785
# α=0.0, λ=0.3, depth=4, η=0.01, sub=0.8, col=0.8 → RMSE: 60.2144
# α=0.0, λ=0.3, depth=4, η=0.01, sub=0.8, col=0.9 → RMSE: 60.1472
# α=0.0, λ=0.3, depth=4, η=0.01, sub=0.8, col=1.0 → RMSE: 60.2108
# α=0.0, λ=0.3, depth=4, η=0.01, sub=0.9, col=0.7 → RMSE: 60.5375
# α=0.0, λ=0.3, depth=4, η=0.01, sub=0.9, col=0.8 → RMSE: 60.3226
# α=0.0, λ=0.3, depth=4, η=0.01, sub=0.9, col=0.9 → RMSE: 60.1274
# α=0.0, λ=0.3, depth=4, η=0.01, sub=0.9, col=1.0 → RMSE: 60.3868
# α=0.0, λ=0.3, depth=4, η=0.01, sub=1.0, col=0.7 → RMSE: 60.9355
# α=0.0, λ=0.3, depth=4, η=0.01, sub=1.0, col=0.8 → RMSE: 60.7234
# α=0.0, λ=0.3, depth=4, η=0.01, sub=1.0, col=0.9 → RMSE: 60.5219
# α=0.0, λ=0.3, depth=4, η=0.01, sub=1.0, col=1.0 → RMSE: 60.6699
# α=0.0, λ=0.3, depth=4, η=0.05, sub=0.7, col=0.7 → RMSE: 56.9878
# α=0.0, λ=0.3, depth=4, η=0.05, sub=0.7, col=0.8 → RMSE: 57.6736
# α=0.0, λ=0.3, depth=4, η=0.05, sub=0.7, col=0.9 → RMSE: 57.2534
# α=0.0, λ=0.3, depth=4, η=0.05, sub=0.7, col=1.0 → RMSE: 57.1340
# α=0.0, λ=0.3, depth=4, η=0.05, sub=0.8, col=0.7 → RMSE: 56.9404
# α=0.0, λ=0.3, depth=4, η=0.05, sub=0.8, col=0.8 → RMSE: 56.6917
# α=0.0, λ=0.3, depth=4, η=0.05, sub=0.8, col=0.9 → RMSE: 57.0251
# α=0.0, λ=0.3, depth=4, η=0.05, sub=0.8, col=1.0 → RMSE: 57.4332
# α=0.0, λ=0.3, depth=4, η=0.05, sub=0.9, col=0.7 → RMSE: 57.7393
# α=0.0, λ=0.3, depth=4, η=0.05, sub=0.9, col=0.8 → RMSE: 57.5594
# α=0.0, λ=0.3, depth=4, η=0.05, sub=0.9, col=0.9 → RMSE: 57.5202
# α=0.0, λ=0.3, depth=4, η=0.05, sub=0.9, col=1.0 → RMSE: 57.8920
# α=0.0, λ=0.3, depth=4, η=0.05, sub=1.0, col=0.7 → RMSE: 57.3350
# α=0.0, λ=0.3, depth=4, η=0.05, sub=1.0, col=0.8 → RMSE: 57.3566
# α=0.0, λ=0.3, depth=4, η=0.05, sub=1.0, col=0.9 → RMSE: 58.0614
# α=0.0, λ=0.3, depth=4, η=0.05, sub=1.0, col=1.0 → RMSE: 57.4274
# α=0.0, λ=0.3, depth=4, η=0.10, sub=0.7, col=0.7 → RMSE: 56.8316
# α=0.0, λ=0.3, depth=4, η=0.10, sub=0.7, col=0.8 → RMSE: 57.5769
# α=0.0, λ=0.3, depth=4, η=0.10, sub=0.7, col=0.9 → RMSE: 56.7119
# α=0.0, λ=0.3, depth=4, η=0.10, sub=0.7, col=1.0 → RMSE: 57.4396
# α=0.0, λ=0.3, depth=4, η=0.10, sub=0.8, col=0.7 → RMSE: 57.4586
# α=0.0, λ=0.3, depth=4, η=0.10, sub=0.8, col=0.8 → RMSE: 57.0899
# α=0.0, λ=0.3, depth=4, η=0.10, sub=0.8, col=0.9 → RMSE: 56.8058
# α=0.0, λ=0.3, depth=4, η=0.10, sub=0.8, col=1.0 → RMSE: 57.6656
# α=0.0, λ=0.3, depth=4, η=0.10, sub=0.9, col=0.7 → RMSE: 58.2572
# α=0.0, λ=0.3, depth=4, η=0.10, sub=0.9, col=0.8 → RMSE: 57.6840
# α=0.0, λ=0.3, depth=4, η=0.10, sub=0.9, col=0.9 → RMSE: 57.6382
# α=0.0, λ=0.3, depth=4, η=0.10, sub=0.9, col=1.0 → RMSE: 57.3016
# α=0.0, λ=0.3, depth=4, η=0.10, sub=1.0, col=0.7 → RMSE: 57.7371
# α=0.0, λ=0.3, depth=4, η=0.10, sub=1.0, col=0.8 → RMSE: 57.2682
# α=0.0, λ=0.3, depth=4, η=0.10, sub=1.0, col=0.9 → RMSE: 57.1142
# α=0.0, λ=0.3, depth=4, η=0.10, sub=1.0, col=1.0 → RMSE: 58.2731
# α=0.0, λ=0.3, depth=4, η=0.20, sub=0.7, col=0.7 → RMSE: 57.6354
# α=0.0, λ=0.3, depth=4, η=0.20, sub=0.7, col=0.8 → RMSE: 57.4378
# α=0.0, λ=0.3, depth=4, η=0.20, sub=0.7, col=0.9 → RMSE: 58.2270
# α=0.0, λ=0.3, depth=4, η=0.20, sub=0.7, col=1.0 → RMSE: 57.4555
# α=0.0, λ=0.3, depth=4, η=0.20, sub=0.8, col=0.7 → RMSE: 57.9784
# α=0.0, λ=0.3, depth=4, η=0.20, sub=0.8, col=0.8 → RMSE: 58.3092
# α=0.0, λ=0.3, depth=4, η=0.20, sub=0.8, col=0.9 → RMSE: 57.9610
# α=0.0, λ=0.3, depth=4, η=0.20, sub=0.8, col=1.0 → RMSE: 57.0844
# α=0.0, λ=0.3, depth=4, η=0.20, sub=0.9, col=0.7 → RMSE: 57.4995
# α=0.0, λ=0.3, depth=4, η=0.20, sub=0.9, col=0.8 → RMSE: 58.0099
# α=0.0, λ=0.3, depth=4, η=0.20, sub=0.9, col=0.9 → RMSE: 59.5807
# α=0.0, λ=0.3, depth=4, η=0.20, sub=0.9, col=1.0 → RMSE: 58.0471
# α=0.0, λ=0.3, depth=4, η=0.20, sub=1.0, col=0.7 → RMSE: 58.1665
# α=0.0, λ=0.3, depth=4, η=0.20, sub=1.0, col=0.8 → RMSE: 57.9676
# α=0.0, λ=0.3, depth=4, η=0.20, sub=1.0, col=0.9 → RMSE: 58.5654
# α=0.0, λ=0.3, depth=4, η=0.20, sub=1.0, col=1.0 → RMSE: 58.7528
# α=0.0, λ=0.3, depth=5, η=0.01, sub=0.7, col=0.7 → RMSE: 60.5230
# α=0.0, λ=0.3, depth=5, η=0.01, sub=0.7, col=0.8 → RMSE: 60.3412
# α=0.0, λ=0.3, depth=5, η=0.01, sub=0.7, col=0.9 → RMSE: 60.2105
# α=0.0, λ=0.3, depth=5, η=0.01, sub=0.7, col=1.0 → RMSE: 59.9649
# α=0.0, λ=0.3, depth=5, η=0.01, sub=0.8, col=0.7 → RMSE: 60.6278
# α=0.0, λ=0.3, depth=5, η=0.01, sub=0.8, col=0.8 → RMSE: 60.4160
# α=0.0, λ=0.3, depth=5, η=0.01, sub=0.8, col=0.9 → RMSE: 60.3626
# α=0.0, λ=0.3, depth=5, η=0.01, sub=0.8, col=1.0 → RMSE: 60.3961
# α=0.0, λ=0.3, depth=5, η=0.01, sub=0.9, col=0.7 → RMSE: 60.6701
# α=0.0, λ=0.3, depth=5, η=0.01, sub=0.9, col=0.8 → RMSE: 60.5280
# α=0.0, λ=0.3, depth=5, η=0.01, sub=0.9, col=0.9 → RMSE: 60.4520
# α=0.0, λ=0.3, depth=5, η=0.01, sub=0.9, col=1.0 → RMSE: 60.5821
# α=0.0, λ=0.3, depth=5, η=0.01, sub=1.0, col=0.7 → RMSE: 61.1230
# α=0.0, λ=0.3, depth=5, η=0.01, sub=1.0, col=0.8 → RMSE: 61.1451
# α=0.0, λ=0.3, depth=5, η=0.01, sub=1.0, col=0.9 → RMSE: 61.3035
# α=0.0, λ=0.3, depth=5, η=0.01, sub=1.0, col=1.0 → RMSE: 61.1443
# α=0.0, λ=0.3, depth=5, η=0.05, sub=0.7, col=0.7 → RMSE: 57.6138
# α=0.0, λ=0.3, depth=5, η=0.05, sub=0.7, col=0.8 → RMSE: 58.2950
# α=0.0, λ=0.3, depth=5, η=0.05, sub=0.7, col=0.9 → RMSE: 57.4858
# α=0.0, λ=0.3, depth=5, η=0.05, sub=0.7, col=1.0 → RMSE: 57.8373
# α=0.0, λ=0.3, depth=5, η=0.05, sub=0.8, col=0.7 → RMSE: 57.3875
# α=0.0, λ=0.3, depth=5, η=0.05, sub=0.8, col=0.8 → RMSE: 57.9926
# α=0.0, λ=0.3, depth=5, η=0.05, sub=0.8, col=0.9 → RMSE: 58.0963
# α=0.0, λ=0.3, depth=5, η=0.05, sub=0.8, col=1.0 → RMSE: 58.0821
# α=0.0, λ=0.3, depth=5, η=0.05, sub=0.9, col=0.7 → RMSE: 58.1346
# α=0.0, λ=0.3, depth=5, η=0.05, sub=0.9, col=0.8 → RMSE: 58.0216
# α=0.0, λ=0.3, depth=5, η=0.05, sub=0.9, col=0.9 → RMSE: 58.2802
# α=0.0, λ=0.3, depth=5, η=0.05, sub=0.9, col=1.0 → RMSE: 58.0972
# α=0.0, λ=0.3, depth=5, η=0.05, sub=1.0, col=0.7 → RMSE: 58.0758
# α=0.0, λ=0.3, depth=5, η=0.05, sub=1.0, col=0.8 → RMSE: 58.7605
# α=0.0, λ=0.3, depth=5, η=0.05, sub=1.0, col=0.9 → RMSE: 58.7539
# α=0.0, λ=0.3, depth=5, η=0.05, sub=1.0, col=1.0 → RMSE: 59.3865
# α=0.0, λ=0.3, depth=5, η=0.10, sub=0.7, col=0.7 → RMSE: 57.9188
# α=0.0, λ=0.3, depth=5, η=0.10, sub=0.7, col=0.8 → RMSE: 58.4366
# α=0.0, λ=0.3, depth=5, η=0.10, sub=0.7, col=0.9 → RMSE: 58.7156
# α=0.0, λ=0.3, depth=5, η=0.10, sub=0.7, col=1.0 → RMSE: 57.9843
# α=0.0, λ=0.3, depth=5, η=0.10, sub=0.8, col=0.7 → RMSE: 58.0615
# α=0.0, λ=0.3, depth=5, η=0.10, sub=0.8, col=0.8 → RMSE: 58.0940
# α=0.0, λ=0.3, depth=5, η=0.10, sub=0.8, col=0.9 → RMSE: 58.6240
# α=0.0, λ=0.3, depth=5, η=0.10, sub=0.8, col=1.0 → RMSE: 58.3515
# α=0.0, λ=0.3, depth=5, η=0.10, sub=0.9, col=0.7 → RMSE: 59.2467
# α=0.0, λ=0.3, depth=5, η=0.10, sub=0.9, col=0.8 → RMSE: 58.9026
# α=0.0, λ=0.3, depth=5, η=0.10, sub=0.9, col=0.9 → RMSE: 58.8014
# α=0.0, λ=0.3, depth=5, η=0.10, sub=0.9, col=1.0 → RMSE: 58.9395
# α=0.0, λ=0.3, depth=5, η=0.10, sub=1.0, col=0.7 → RMSE: 58.3835
# α=0.0, λ=0.3, depth=5, η=0.10, sub=1.0, col=0.8 → RMSE: 58.7552
# α=0.0, λ=0.3, depth=5, η=0.10, sub=1.0, col=0.9 → RMSE: 58.8589
# α=0.0, λ=0.3, depth=5, η=0.10, sub=1.0, col=1.0 → RMSE: 59.2754
# α=0.0, λ=0.3, depth=5, η=0.20, sub=0.7, col=0.7 → RMSE: 59.8980
# α=0.0, λ=0.3, depth=5, η=0.20, sub=0.7, col=0.8 → RMSE: 58.4362
# α=0.0, λ=0.3, depth=5, η=0.20, sub=0.7, col=0.9 → RMSE: 58.0751
# α=0.0, λ=0.3, depth=5, η=0.20, sub=0.7, col=1.0 → RMSE: 57.7875
# α=0.0, λ=0.3, depth=5, η=0.20, sub=0.8, col=0.7 → RMSE: 58.4529
# α=0.0, λ=0.3, depth=5, η=0.20, sub=0.8, col=0.8 → RMSE: 59.3989
# α=0.0, λ=0.3, depth=5, η=0.20, sub=0.8, col=0.9 → RMSE: 59.3106
# α=0.0, λ=0.3, depth=5, η=0.20, sub=0.8, col=1.0 → RMSE: 58.2674
# α=0.0, λ=0.3, depth=5, η=0.20, sub=0.9, col=0.7 → RMSE: 59.3299
# α=0.0, λ=0.3, depth=5, η=0.20, sub=0.9, col=0.8 → RMSE: 58.4622
# α=0.0, λ=0.3, depth=5, η=0.20, sub=0.9, col=0.9 → RMSE: 59.8129
# α=0.0, λ=0.3, depth=5, η=0.20, sub=0.9, col=1.0 → RMSE: 59.7120
# α=0.0, λ=0.3, depth=5, η=0.20, sub=1.0, col=0.7 → RMSE: 58.3598
# α=0.0, λ=0.3, depth=5, η=0.20, sub=1.0, col=0.8 → RMSE: 58.6951
# α=0.0, λ=0.3, depth=5, η=0.20, sub=1.0, col=0.9 → RMSE: 58.1209
# α=0.0, λ=0.3, depth=5, η=0.20, sub=1.0, col=1.0 → RMSE: 60.4682
# α=0.0, λ=0.3, depth=6, η=0.01, sub=0.7, col=0.7 → RMSE: 60.7803
# α=0.0, λ=0.3, depth=6, η=0.01, sub=0.7, col=0.8 → RMSE: 60.5551
# α=0.0, λ=0.3, depth=6, η=0.01, sub=0.7, col=0.9 → RMSE: 60.4484
# α=0.0, λ=0.3, depth=6, η=0.01, sub=0.7, col=1.0 → RMSE: 60.2442
# α=0.0, λ=0.3, depth=6, η=0.01, sub=0.8, col=0.7 → RMSE: 60.8352
# α=0.0, λ=0.3, depth=6, η=0.01, sub=0.8, col=0.8 → RMSE: 60.5612
# α=0.0, λ=0.3, depth=6, η=0.01, sub=0.8, col=0.9 → RMSE: 60.7652
# α=0.0, λ=0.3, depth=6, η=0.01, sub=0.8, col=1.0 → RMSE: 60.7724
# α=0.0, λ=0.3, depth=6, η=0.01, sub=0.9, col=0.7 → RMSE: 60.9934
# α=0.0, λ=0.3, depth=6, η=0.01, sub=0.9, col=0.8 → RMSE: 60.9307
# α=0.0, λ=0.3, depth=6, η=0.01, sub=0.9, col=0.9 → RMSE: 61.0035
# α=0.0, λ=0.3, depth=6, η=0.01, sub=0.9, col=1.0 → RMSE: 61.0696
# α=0.0, λ=0.3, depth=6, η=0.01, sub=1.0, col=0.7 → RMSE: 61.3810
# α=0.0, λ=0.3, depth=6, η=0.01, sub=1.0, col=0.8 → RMSE: 61.7615
# α=0.0, λ=0.3, depth=6, η=0.01, sub=1.0, col=0.9 → RMSE: 61.6955
# α=0.0, λ=0.3, depth=6, η=0.01, sub=1.0, col=1.0 → RMSE: 61.9510
# α=0.0, λ=0.3, depth=6, η=0.05, sub=0.7, col=0.7 → RMSE: 57.4011
# α=0.0, λ=0.3, depth=6, η=0.05, sub=0.7, col=0.8 → RMSE: 59.0181
# α=0.0, λ=0.3, depth=6, η=0.05, sub=0.7, col=0.9 → RMSE: 58.2577
# α=0.0, λ=0.3, depth=6, η=0.05, sub=0.7, col=1.0 → RMSE: 58.5765
# α=0.0, λ=0.3, depth=6, η=0.05, sub=0.8, col=0.7 → RMSE: 57.8673
# α=0.0, λ=0.3, depth=6, η=0.05, sub=0.8, col=0.8 → RMSE: 59.0314
# α=0.0, λ=0.3, depth=6, η=0.05, sub=0.8, col=0.9 → RMSE: 58.6023
# α=0.0, λ=0.3, depth=6, η=0.05, sub=0.8, col=1.0 → RMSE: 58.6909
# α=0.0, λ=0.3, depth=6, η=0.05, sub=0.9, col=0.7 → RMSE: 58.9034
# α=0.0, λ=0.3, depth=6, η=0.05, sub=0.9, col=0.8 → RMSE: 58.5778
# α=0.0, λ=0.3, depth=6, η=0.05, sub=0.9, col=0.9 → RMSE: 59.2753
# α=0.0, λ=0.3, depth=6, η=0.05, sub=0.9, col=1.0 → RMSE: 59.6839
# α=0.0, λ=0.3, depth=6, η=0.05, sub=1.0, col=0.7 → RMSE: 59.2433
# α=0.0, λ=0.3, depth=6, η=0.05, sub=1.0, col=0.8 → RMSE: 60.0816
# α=0.0, λ=0.3, depth=6, η=0.05, sub=1.0, col=0.9 → RMSE: 60.0090
# α=0.0, λ=0.3, depth=6, η=0.05, sub=1.0, col=1.0 → RMSE: 60.2883
# α=0.0, λ=0.3, depth=6, η=0.10, sub=0.7, col=0.7 → RMSE: 58.5954
# α=0.0, λ=0.3, depth=6, η=0.10, sub=0.7, col=0.8 → RMSE: 59.1333
# α=0.0, λ=0.3, depth=6, η=0.10, sub=0.7, col=0.9 → RMSE: 59.5588
# α=0.0, λ=0.3, depth=6, η=0.10, sub=0.7, col=1.0 → RMSE: 59.6218
# α=0.0, λ=0.3, depth=6, η=0.10, sub=0.8, col=0.7 → RMSE: 58.3105
# α=0.0, λ=0.3, depth=6, η=0.10, sub=0.8, col=0.8 → RMSE: 59.4831
# α=0.0, λ=0.3, depth=6, η=0.10, sub=0.8, col=0.9 → RMSE: 60.2382
# α=0.0, λ=0.3, depth=6, η=0.10, sub=0.8, col=1.0 → RMSE: 59.3813
# α=0.0, λ=0.3, depth=6, η=0.10, sub=0.9, col=0.7 → RMSE: 58.8673
# α=0.0, λ=0.3, depth=6, η=0.10, sub=0.9, col=0.8 → RMSE: 59.2603
# α=0.0, λ=0.3, depth=6, η=0.10, sub=0.9, col=0.9 → RMSE: 59.8156
# α=0.0, λ=0.3, depth=6, η=0.10, sub=0.9, col=1.0 → RMSE: 59.7298
# α=0.0, λ=0.3, depth=6, η=0.10, sub=1.0, col=0.7 → RMSE: 60.2525
# α=0.0, λ=0.3, depth=6, η=0.10, sub=1.0, col=0.8 → RMSE: 60.2007
# α=0.0, λ=0.3, depth=6, η=0.10, sub=1.0, col=0.9 → RMSE: 60.1084
# α=0.0, λ=0.3, depth=6, η=0.10, sub=1.0, col=1.0 → RMSE: 60.4522
# α=0.0, λ=0.3, depth=6, η=0.20, sub=0.7, col=0.7 → RMSE: 58.8567
# α=0.0, λ=0.3, depth=6, η=0.20, sub=0.7, col=0.8 → RMSE: 60.6802
# α=0.0, λ=0.3, depth=6, η=0.20, sub=0.7, col=0.9 → RMSE: 60.8431
# α=0.0, λ=0.3, depth=6, η=0.20, sub=0.7, col=1.0 → RMSE: 60.3839
# α=0.0, λ=0.3, depth=6, η=0.20, sub=0.8, col=0.7 → RMSE: 61.0638
# α=0.0, λ=0.3, depth=6, η=0.20, sub=0.8, col=0.8 → RMSE: 59.9595
# α=0.0, λ=0.3, depth=6, η=0.20, sub=0.8, col=0.9 → RMSE: 61.0847
# α=0.0, λ=0.3, depth=6, η=0.20, sub=0.8, col=1.0 → RMSE: 60.8537
# α=0.0, λ=0.3, depth=6, η=0.20, sub=0.9, col=0.7 → RMSE: 59.3836
# α=0.0, λ=0.3, depth=6, η=0.20, sub=0.9, col=0.8 → RMSE: 59.9795
# α=0.0, λ=0.3, depth=6, η=0.20, sub=0.9, col=0.9 → RMSE: 60.3960
# α=0.0, λ=0.3, depth=6, η=0.20, sub=0.9, col=1.0 → RMSE: 62.2040
# α=0.0, λ=0.3, depth=6, η=0.20, sub=1.0, col=0.7 → RMSE: 59.5549
# α=0.0, λ=0.3, depth=6, η=0.20, sub=1.0, col=0.8 → RMSE: 60.5240
# α=0.0, λ=0.3, depth=6, η=0.20, sub=1.0, col=0.9 → RMSE: 60.3277
# α=0.0, λ=0.3, depth=6, η=0.20, sub=1.0, col=1.0 → RMSE: 60.8173
# α=0.0, λ=0.5, depth=3, η=0.01, sub=0.7, col=0.7 → RMSE: 60.5602
# α=0.0, λ=0.5, depth=3, η=0.01, sub=0.7, col=0.8 → RMSE: 60.4639
# α=0.0, λ=0.5, depth=3, η=0.01, sub=0.7, col=0.9 → RMSE: 60.1746
# α=0.0, λ=0.5, depth=3, η=0.01, sub=0.7, col=1.0 → RMSE: 60.0268
# α=0.0, λ=0.5, depth=3, η=0.01, sub=0.8, col=0.7 → RMSE: 60.5639
# α=0.0, λ=0.5, depth=3, η=0.01, sub=0.8, col=0.8 → RMSE: 60.4169
# α=0.0, λ=0.5, depth=3, η=0.01, sub=0.8, col=0.9 → RMSE: 60.3305
# α=0.0, λ=0.5, depth=3, η=0.01, sub=0.8, col=1.0 → RMSE: 60.2606
# α=0.0, λ=0.5, depth=3, η=0.01, sub=0.9, col=0.7 → RMSE: 60.6190
# α=0.0, λ=0.5, depth=3, η=0.01, sub=0.9, col=0.8 → RMSE: 60.4726
# α=0.0, λ=0.5, depth=3, η=0.01, sub=0.9, col=0.9 → RMSE: 60.2465
# α=0.0, λ=0.5, depth=3, η=0.01, sub=0.9, col=1.0 → RMSE: 60.2856
# α=0.0, λ=0.5, depth=3, η=0.01, sub=1.0, col=0.7 → RMSE: 60.8530
# α=0.0, λ=0.5, depth=3, η=0.01, sub=1.0, col=0.8 → RMSE: 60.6634
# α=0.0, λ=0.5, depth=3, η=0.01, sub=1.0, col=0.9 → RMSE: 60.6790
# α=0.0, λ=0.5, depth=3, η=0.01, sub=1.0, col=1.0 → RMSE: 60.6546
# α=0.0, λ=0.5, depth=3, η=0.05, sub=0.7, col=0.7 → RMSE: 56.3958
# α=0.0, λ=0.5, depth=3, η=0.05, sub=0.7, col=0.8 → RMSE: 56.1237
# α=0.0, λ=0.5, depth=3, η=0.05, sub=0.7, col=0.9 → RMSE: 56.4616
# α=0.0, λ=0.5, depth=3, η=0.05, sub=0.7, col=1.0 → RMSE: 56.6711
# α=0.0, λ=0.5, depth=3, η=0.05, sub=0.8, col=0.7 → RMSE: 56.5112
# α=0.0, λ=0.5, depth=3, η=0.05, sub=0.8, col=0.8 → RMSE: 56.4221
# α=0.0, λ=0.5, depth=3, η=0.05, sub=0.8, col=0.9 → RMSE: 56.3694
# α=0.0, λ=0.5, depth=3, η=0.05, sub=0.8, col=1.0 → RMSE: 56.6706
# α=0.0, λ=0.5, depth=3, η=0.05, sub=0.9, col=0.7 → RMSE: 56.2821
# α=0.0, λ=0.5, depth=3, η=0.05, sub=0.9, col=0.8 → RMSE: 56.4535
# α=0.0, λ=0.5, depth=3, η=0.05, sub=0.9, col=0.9 → RMSE: 56.5127
# α=0.0, λ=0.5, depth=3, η=0.05, sub=0.9, col=1.0 → RMSE: 56.1385
# α=0.0, λ=0.5, depth=3, η=0.05, sub=1.0, col=0.7 → RMSE: 56.2925
# α=0.0, λ=0.5, depth=3, η=0.05, sub=1.0, col=0.8 → RMSE: 56.2469
# α=0.0, λ=0.5, depth=3, η=0.05, sub=1.0, col=0.9 → RMSE: 56.4620
# α=0.0, λ=0.5, depth=3, η=0.05, sub=1.0, col=1.0 → RMSE: 56.4059
# α=0.0, λ=0.5, depth=3, η=0.10, sub=0.7, col=0.7 → RMSE: 55.9253
# α=0.0, λ=0.5, depth=3, η=0.10, sub=0.7, col=0.8 → RMSE: 56.4594
# α=0.0, λ=0.5, depth=3, η=0.10, sub=0.7, col=0.9 → RMSE: 56.3909
# α=0.0, λ=0.5, depth=3, η=0.10, sub=0.7, col=1.0 → RMSE: 55.7827
# α=0.0, λ=0.5, depth=3, η=0.10, sub=0.8, col=0.7 → RMSE: 56.2176
# α=0.0, λ=0.5, depth=3, η=0.10, sub=0.8, col=0.8 → RMSE: 55.9699
# α=0.0, λ=0.5, depth=3, η=0.10, sub=0.8, col=0.9 → RMSE: 56.1632
# α=0.0, λ=0.5, depth=3, η=0.10, sub=0.8, col=1.0 → RMSE: 56.3282
# α=0.0, λ=0.5, depth=3, η=0.10, sub=0.9, col=0.7 → RMSE: 56.7373
# α=0.0, λ=0.5, depth=3, η=0.10, sub=0.9, col=0.8 → RMSE: 56.5400
# α=0.0, λ=0.5, depth=3, η=0.10, sub=0.9, col=0.9 → RMSE: 56.4207
# α=0.0, λ=0.5, depth=3, η=0.10, sub=0.9, col=1.0 → RMSE: 56.5095
# α=0.0, λ=0.5, depth=3, η=0.10, sub=1.0, col=0.7 → RMSE: 56.3038
# α=0.0, λ=0.5, depth=3, η=0.10, sub=1.0, col=0.8 → RMSE: 56.3539
# α=0.0, λ=0.5, depth=3, η=0.10, sub=1.0, col=0.9 → RMSE: 56.2133
# α=0.0, λ=0.5, depth=3, η=0.10, sub=1.0, col=1.0 → RMSE: 56.5043
# α=0.0, λ=0.5, depth=3, η=0.20, sub=0.7, col=0.7 → RMSE: 56.3034
# α=0.0, λ=0.5, depth=3, η=0.20, sub=0.7, col=0.8 → RMSE: 57.2698
# α=0.0, λ=0.5, depth=3, η=0.20, sub=0.7, col=0.9 → RMSE: 57.6223
# α=0.0, λ=0.5, depth=3, η=0.20, sub=0.7, col=1.0 → RMSE: 56.8650
# α=0.0, λ=0.5, depth=3, η=0.20, sub=0.8, col=0.7 → RMSE: 56.4280
# α=0.0, λ=0.5, depth=3, η=0.20, sub=0.8, col=0.8 → RMSE: 56.4478
# α=0.0, λ=0.5, depth=3, η=0.20, sub=0.8, col=0.9 → RMSE: 57.0870
# α=0.0, λ=0.5, depth=3, η=0.20, sub=0.8, col=1.0 → RMSE: 56.6472
# α=0.0, λ=0.5, depth=3, η=0.20, sub=0.9, col=0.7 → RMSE: 56.3428
# α=0.0, λ=0.5, depth=3, η=0.20, sub=0.9, col=0.8 → RMSE: 56.8132
# α=0.0, λ=0.5, depth=3, η=0.20, sub=0.9, col=0.9 → RMSE: 56.5979
# α=0.0, λ=0.5, depth=3, η=0.20, sub=0.9, col=1.0 → RMSE: 56.3291
# α=0.0, λ=0.5, depth=3, η=0.20, sub=1.0, col=0.7 → RMSE: 56.4791
# α=0.0, λ=0.5, depth=3, η=0.20, sub=1.0, col=0.8 → RMSE: 56.6325
# α=0.0, λ=0.5, depth=3, η=0.20, sub=1.0, col=0.9 → RMSE: 56.6669
# α=0.0, λ=0.5, depth=3, η=0.20, sub=1.0, col=1.0 → RMSE: 56.5449
# α=0.0, λ=0.5, depth=4, η=0.01, sub=0.7, col=0.7 → RMSE: 60.4914
# α=0.0, λ=0.5, depth=4, η=0.01, sub=0.7, col=0.8 → RMSE: 60.4249
# α=0.0, λ=0.5, depth=4, η=0.01, sub=0.7, col=0.9 → RMSE: 60.1667
# α=0.0, λ=0.5, depth=4, η=0.01, sub=0.7, col=1.0 → RMSE: 60.0646
# α=0.0, λ=0.5, depth=4, η=0.01, sub=0.8, col=0.7 → RMSE: 60.5717
# α=0.0, λ=0.5, depth=4, η=0.01, sub=0.8, col=0.8 → RMSE: 60.2498
# α=0.0, λ=0.5, depth=4, η=0.01, sub=0.8, col=0.9 → RMSE: 60.1747
# α=0.0, λ=0.5, depth=4, η=0.01, sub=0.8, col=1.0 → RMSE: 60.3336
# α=0.0, λ=0.5, depth=4, η=0.01, sub=0.9, col=0.7 → RMSE: 60.6269
# α=0.0, λ=0.5, depth=4, η=0.01, sub=0.9, col=0.8 → RMSE: 60.3271
# α=0.0, λ=0.5, depth=4, η=0.01, sub=0.9, col=0.9 → RMSE: 60.2068
# α=0.0, λ=0.5, depth=4, η=0.01, sub=0.9, col=1.0 → RMSE: 60.4144
# α=0.0, λ=0.5, depth=4, η=0.01, sub=1.0, col=0.7 → RMSE: 60.9386
# α=0.0, λ=0.5, depth=4, η=0.01, sub=1.0, col=0.8 → RMSE: 60.7516
# α=0.0, λ=0.5, depth=4, η=0.01, sub=1.0, col=0.9 → RMSE: 60.5887
# α=0.0, λ=0.5, depth=4, η=0.01, sub=1.0, col=1.0 → RMSE: 60.7105
# α=0.0, λ=0.5, depth=4, η=0.05, sub=0.7, col=0.7 → RMSE: 56.7551
# α=0.0, λ=0.5, depth=4, η=0.05, sub=0.7, col=0.8 → RMSE: 57.4652
# α=0.0, λ=0.5, depth=4, η=0.05, sub=0.7, col=0.9 → RMSE: 56.9763
# α=0.0, λ=0.5, depth=4, η=0.05, sub=0.7, col=1.0 → RMSE: 57.2679
# α=0.0, λ=0.5, depth=4, η=0.05, sub=0.8, col=0.7 → RMSE: 56.8676
# α=0.0, λ=0.5, depth=4, η=0.05, sub=0.8, col=0.8 → RMSE: 56.8935
# α=0.0, λ=0.5, depth=4, η=0.05, sub=0.8, col=0.9 → RMSE: 57.1552
# α=0.0, λ=0.5, depth=4, η=0.05, sub=0.8, col=1.0 → RMSE: 57.3593
# α=0.0, λ=0.5, depth=4, η=0.05, sub=0.9, col=0.7 → RMSE: 57.7289
# α=0.0, λ=0.5, depth=4, η=0.05, sub=0.9, col=0.8 → RMSE: 57.6889
# α=0.0, λ=0.5, depth=4, η=0.05, sub=0.9, col=0.9 → RMSE: 57.3389
# α=0.0, λ=0.5, depth=4, η=0.05, sub=0.9, col=1.0 → RMSE: 57.6134
# α=0.0, λ=0.5, depth=4, η=0.05, sub=1.0, col=0.7 → RMSE: 57.7338
# α=0.0, λ=0.5, depth=4, η=0.05, sub=1.0, col=0.8 → RMSE: 57.5704
# α=0.0, λ=0.5, depth=4, η=0.05, sub=1.0, col=0.9 → RMSE: 57.9625
# α=0.0, λ=0.5, depth=4, η=0.05, sub=1.0, col=1.0 → RMSE: 57.7493
# α=0.0, λ=0.5, depth=4, η=0.10, sub=0.7, col=0.7 → RMSE: 57.0782
# α=0.0, λ=0.5, depth=4, η=0.10, sub=0.7, col=0.8 → RMSE: 57.8122
# α=0.0, λ=0.5, depth=4, η=0.10, sub=0.7, col=0.9 → RMSE: 57.2250
# α=0.0, λ=0.5, depth=4, η=0.10, sub=0.7, col=1.0 → RMSE: 57.8986
# α=0.0, λ=0.5, depth=4, η=0.10, sub=0.8, col=0.7 → RMSE: 57.7655
# α=0.0, λ=0.5, depth=4, η=0.10, sub=0.8, col=0.8 → RMSE: 57.1414
# α=0.0, λ=0.5, depth=4, η=0.10, sub=0.8, col=0.9 → RMSE: 57.2148
# α=0.0, λ=0.5, depth=4, η=0.10, sub=0.8, col=1.0 → RMSE: 57.5392
# α=0.0, λ=0.5, depth=4, η=0.10, sub=0.9, col=0.7 → RMSE: 58.2667
# α=0.0, λ=0.5, depth=4, η=0.10, sub=0.9, col=0.8 → RMSE: 57.1757
# α=0.0, λ=0.5, depth=4, η=0.10, sub=0.9, col=0.9 → RMSE: 57.4102
# α=0.0, λ=0.5, depth=4, η=0.10, sub=0.9, col=1.0 → RMSE: 57.4979
# α=0.0, λ=0.5, depth=4, η=0.10, sub=1.0, col=0.7 → RMSE: 57.4402
# α=0.0, λ=0.5, depth=4, η=0.10, sub=1.0, col=0.8 → RMSE: 57.5672
# α=0.0, λ=0.5, depth=4, η=0.10, sub=1.0, col=0.9 → RMSE: 57.1792
# α=0.0, λ=0.5, depth=4, η=0.10, sub=1.0, col=1.0 → RMSE: 57.1866
# α=0.0, λ=0.5, depth=4, η=0.20, sub=0.7, col=0.7 → RMSE: 57.7517
# α=0.0, λ=0.5, depth=4, η=0.20, sub=0.7, col=0.8 → RMSE: 57.4075
# α=0.0, λ=0.5, depth=4, η=0.20, sub=0.7, col=0.9 → RMSE: 57.7150
# α=0.0, λ=0.5, depth=4, η=0.20, sub=0.7, col=1.0 → RMSE: 57.9316
# α=0.0, λ=0.5, depth=4, η=0.20, sub=0.8, col=0.7 → RMSE: 57.9078
# α=0.0, λ=0.5, depth=4, η=0.20, sub=0.8, col=0.8 → RMSE: 58.6093
# α=0.0, λ=0.5, depth=4, η=0.20, sub=0.8, col=0.9 → RMSE: 58.6936
# α=0.0, λ=0.5, depth=4, η=0.20, sub=0.8, col=1.0 → RMSE: 57.8407
# α=0.0, λ=0.5, depth=4, η=0.20, sub=0.9, col=0.7 → RMSE: 57.5260
# α=0.0, λ=0.5, depth=4, η=0.20, sub=0.9, col=0.8 → RMSE: 57.3984
# α=0.0, λ=0.5, depth=4, η=0.20, sub=0.9, col=0.9 → RMSE: 59.5703
# α=0.0, λ=0.5, depth=4, η=0.20, sub=0.9, col=1.0 → RMSE: 58.0327
# α=0.0, λ=0.5, depth=4, η=0.20, sub=1.0, col=0.7 → RMSE: 58.1408
# α=0.0, λ=0.5, depth=4, η=0.20, sub=1.0, col=0.8 → RMSE: 57.5081
# α=0.0, λ=0.5, depth=4, η=0.20, sub=1.0, col=0.9 → RMSE: 58.2589
# α=0.0, λ=0.5, depth=4, η=0.20, sub=1.0, col=1.0 → RMSE: 57.9730
# α=0.0, λ=0.5, depth=5, η=0.01, sub=0.7, col=0.7 → RMSE: 60.6084
# α=0.0, λ=0.5, depth=5, η=0.01, sub=0.7, col=0.8 → RMSE: 60.3504
# α=0.0, λ=0.5, depth=5, η=0.01, sub=0.7, col=0.9 → RMSE: 60.2876
# α=0.0, λ=0.5, depth=5, η=0.01, sub=0.7, col=1.0 → RMSE: 60.1229
# α=0.0, λ=0.5, depth=5, η=0.01, sub=0.8, col=0.7 → RMSE: 60.6539
# α=0.0, λ=0.5, depth=5, η=0.01, sub=0.8, col=0.8 → RMSE: 60.3620
# α=0.0, λ=0.5, depth=5, η=0.01, sub=0.8, col=0.9 → RMSE: 60.4476
# α=0.0, λ=0.5, depth=5, η=0.01, sub=0.8, col=1.0 → RMSE: 60.4359
# α=0.0, λ=0.5, depth=5, η=0.01, sub=0.9, col=0.7 → RMSE: 60.8651
# α=0.0, λ=0.5, depth=5, η=0.01, sub=0.9, col=0.8 → RMSE: 60.5184
# α=0.0, λ=0.5, depth=5, η=0.01, sub=0.9, col=0.9 → RMSE: 60.4706
# α=0.0, λ=0.5, depth=5, η=0.01, sub=0.9, col=1.0 → RMSE: 60.5897
# α=0.0, λ=0.5, depth=5, η=0.01, sub=1.0, col=0.7 → RMSE: 61.2167
# α=0.0, λ=0.5, depth=5, η=0.01, sub=1.0, col=0.8 → RMSE: 61.0884
# α=0.0, λ=0.5, depth=5, η=0.01, sub=1.0, col=0.9 → RMSE: 61.0538
# α=0.0, λ=0.5, depth=5, η=0.01, sub=1.0, col=1.0 → RMSE: 61.0167
# α=0.0, λ=0.5, depth=5, η=0.05, sub=0.7, col=0.7 → RMSE: 57.7789
# α=0.0, λ=0.5, depth=5, η=0.05, sub=0.7, col=0.8 → RMSE: 58.2628
# α=0.0, λ=0.5, depth=5, η=0.05, sub=0.7, col=0.9 → RMSE: 57.9071
# α=0.0, λ=0.5, depth=5, η=0.05, sub=0.7, col=1.0 → RMSE: 57.3631
# α=0.0, λ=0.5, depth=5, η=0.05, sub=0.8, col=0.7 → RMSE: 57.7834
# α=0.0, λ=0.5, depth=5, η=0.05, sub=0.8, col=0.8 → RMSE: 57.8215
# α=0.0, λ=0.5, depth=5, η=0.05, sub=0.8, col=0.9 → RMSE: 57.8839
# α=0.0, λ=0.5, depth=5, η=0.05, sub=0.8, col=1.0 → RMSE: 58.0678
# α=0.0, λ=0.5, depth=5, η=0.05, sub=0.9, col=0.7 → RMSE: 58.4830
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 44
#      33 params = {
#      34     'objective':        'reg:squarederror',
#      35     'alpha':            alpha,
#    (...)     40     'colsample_bytree': colsample
#      41 }
#      43 # Eseguo la cross‐validation con early stopping
# ---> 44 cv_results = xgb.cv(
#      45     params,
#      46     dtrain,
#      47     num_boost_round=100,
#      48     nfold=5,
#      49     metrics="rmse",
#      50     early_stopping_rounds=10,
#      51     seed=42,
#      52     verbose_eval=False
#      53 )
#      54 # Estraggo il valore minimo di test-rmse-mean
#      55 mean_rmse = cv_results['test-rmse-mean'].min()
#
# File c:\Users\fabri\Desktop\MarcoPatierno_DepositoCorsoPython\env\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File c:\Users\fabri\Desktop\MarcoPatierno_DepositoCorsoPython\env\Lib\site-packages\xgboost\training.py:581, in cv(params, dtrain, num_boost_round, nfold, stratified, folds, metrics, obj, maximize, early_stopping_rounds, fpreproc, as_pandas, verbose_eval, show_stdv, seed, callbacks, shuffle, custom_metric)
#     579 if callbacks_container.before_iteration(booster, i, dtrain, None):
#     580     break
# --> 581 booster.update(i, obj)
#     583 should_break = callbacks_container.after_iteration(booster, i, dtrain, None)
#     584 res = callbacks_container.aggregated_cv
#
# File c:\Users\fabri\Desktop\MarcoPatierno_DepositoCorsoPython\env\Lib\site-packages\xgboost\training.py:229, in _PackedBooster.update(self, iteration, obj)
#     227 """Iterate through folds for update"""
#     228 for fold in self.cvfolds:
# --> 229     fold.update(iteration, obj)
#
# File c:\Users\fabri\Desktop\MarcoPatierno_DepositoCorsoPython\env\Lib\site-packages\xgboost\training.py:215, in CVPack.update(self, iteration, fobj)
#     213 def update(self, iteration: int, fobj: Optional[Objective]) -> None:
#     214     """ "Update the boosters for one iteration"""
# --> 215     self.bst.update(self.dtrain, iteration, fobj)
#
# File c:\Users\fabri\Desktop\MarcoPatierno_DepositoCorsoPython\env\Lib\site-packages\xgboost\core.py:2243, in Booster.update(self, dtrain, iteration, fobj)
#    2241 if not isinstance(dtrain, DMatrix):
#    2242     raise TypeError(f"invalid training matrix: {type(dtrain).__name__}")
# -> 2243 self._assign_dmatrix_features(dtrain)
#    2245 if fobj is None:
#    2246     _check_call(
#    2247         _LIB.XGBoosterUpdateOneIter(
#    2248             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2249         )
#    2250     )
#
# File c:\Users\fabri\Desktop\MarcoPatierno_DepositoCorsoPython\env\Lib\site-packages\xgboost\core.py:3200, in Booster._assign_dmatrix_features(self, data)
#    3197 if data.num_row() == 0:
#    3198     return
# -> 3200 fn = data.feature_names
#    3201 ft = data.feature_types
#    3203 if self.feature_names is None:
#
# File c:\Users\fabri\Desktop\MarcoPatierno_DepositoCorsoPython\env\Lib\site-packages\xgboost\core.py:1318, in DMatrix.feature_names(self)
#    1315 length = c_bst_ulong()
#    1316 sarr = ctypes.POINTER(ctypes.c_char_p)()
#    1317 _check_call(
# -> 1318     _LIB.XGDMatrixGetStrFeatureInfo(
#    1319         self.handle,
#    1320         c_str("feature_name"),
#    1321         ctypes.byref(length),
#    1322         ctypes.byref(sarr),
#    1323     )
#    1324 )
#    1325 feature_names = from_cstr_to_pystr(sarr, length)
#    1326 if not feature_names:
#
# KeyboardInterrupt:
